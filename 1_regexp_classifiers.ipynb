# %% [markdown]
# # Text Analytics Lab 1: Regular Expressions and Classifiers
#
# ### Learning Outcomes
# * Be able to set up a Python and Jupyter notebook environment for text analytics
# * Understand how to use regular expressions to preprocess text
# * Know how to carry out text normalisation and train and test naïve Bayes and logistic regression classifiers.
# * Be able to examine learned model parameters and explain how each classifier makes a decision.
#
# ### Outline
#
# 1. Getting started: how to set up your environment, Jupyter notebooks introduction
# 1. Acquiring raw text data
# 1. Regular expressions
# 1. Text normalisation
# 1. Training and evaluating naïve Bayes using Scikit-learn.
# 1. Training and evaluating logistic regression using Scikit-learn.
# 1. Optional extension: lemmatization and bigram features.
# 1. Optional extensions: lexicon features.
#
# ### How To Complete This Lab
#
# Read the text and the code then look for 'TODOs' that instruct you to complete some missing code. Look out for 'QUESTIONS' which you should try to answer before moving on to the next cell. Aim to work through the lab during the scheduled lab hours. To get help, you can talk to TAs or the lecturer during the labs, post questions to the Blackboard discussion board or on Teams, or ask a question in the lectures.
#
# The labs *will not be marked*. However, they will prepare you for the coursework, so try to keep up with the weekly labs and have fun with the exercises! To understand what's going on inside the methods we use here, make sure to watch the lecture videos for the same week.

# %% [markdown]
# ## 1. Getting Started
#
# ### Setting up your environment
#
# We recommend using ```conda``` to create an environment with the correct versions of all the packages you need for these labs. You can install either Anaconda or Miniconda, which will include the ```conda``` program.
#
# We provide a .yml file that lists all the packages you will need, and the versions that we have tested the labs with. You can use this file to create your environment as follows.
#
# 1. Open a terminal. Use the command line to navigate to the directory containing this notebook and the file ```crossplatform_environment.yml```. You can use the command ```cd``` to change directory on the command line.
#
# 1. For Lab machines in MVB 2.11 only: Load the Anaconda module: ```module load anaconda/3-2024```.
#
# 1. Run the conda program by typing ```conda env create -f crossplatform_environment.yml```, then answer any questions that appear on the command line.
#
# 1. Activate the environment by running the command ```conda activate text_analytics```.
#
# 1. Make kernel available in Jupyter: ```python -m ipykernel install --user --name=text_analytics```.
#
# 1. Relaunch Jupyter: shutdown any running instances, and then type ```jupyter lab``` into your command line.
#
# 1. Find this notebook and open it up again.
#
# 1. Go to the top menu and change the kernel: click on 'Kernel'--> 'Change kernel' --> text_analytics.
#
# You should now be ready to go!
#
# The core libraries we will be using in this unit are:
#
# - [Datasets](https://huggingface.co/docs/datasets/), produced by HuggingFace, is a hub for lots of interesting text datasets.
# - [NLTK](https://www.nltk.org), a comprehensive NLP library.
# - [Scikit-learn](https://scikit-learn.org/stable/user_guide.html), for machine learning and classifier evaluation.
# - [Gensim](https://radimrehurek.com/gensim/), for topic modelling.
# - [Transformers](https://huggingface.co/docs/transformers/en/index), for state-of-the-art NLP models.
# - [PyTorch](https://pytorch.org/), a framework for deep learning.
#
# The libraries above have good documentation, which is available either online (links above) or via Python itself, e.g. `help(numpy.array)` in the Python interpreter.
#
# ### Refreshers for Python and Jupyter
#
# **Skip this part if you're already familiar with Python and Jupyter notebooks.**
#
# This lab assumes you have used Python and Jupyter Notebooks before.
#
# For an introduction or refresher on Python, see the [Introduction to Python lab](https://github.com/UoB-COMS21202/lab_sheets_public/tree/master/lab_1) or the University of Bristol [Beginning Python](https://milliams.gitlab.io/beginning_python/) course. If you are a beginner with Python, you might also like to look at Chapter 1 in the NLTK book, which also provides a guide for "getting started with Python": https://www.nltk.org/book/
#
# The labs will be run on [Jupyter Notebook](http://jupyter.org/), an interactive coding environment embedded in a webpage supporting various programing languages (Python, R, Lua, etc.) through the concept of kernels.
#
# It allows you to enrich your code with complex comments formatted in Markdown and $\LaTeX$, as well as to place the results of your computation right below your code.
#
# Notebooks are organised in cells which can contain either code (in our case, this will be Python code) or text, which can be easily and nicely formatted using the Markdown notation.
#
# To edit an already existing cell simply double-click on it. You can use the toolbar to insert new cells, edit and delete them (or use keyboard shortcuts which are very handy to speed up coding).
#
# Cells can be run by hitting `shift+enter` when editing a cell or by clicking on the `Run` button at the top. Running a Markdown cell will simply display the formatted text, while running a code cell will execute the commands executed in it. Create new cells with the keyboard shortcut `esc` followed by `A` or `B`.
#
# **Note**: when you run a code cell, all the created variables, implemented functions and imported libraries will be then available to every other code cell. It is commonly assumed that cells will be run in the correct sequence and running them repeatedly or out-of-order may sometimes cause errors. To reset all variables and functions (for debugging) simply click `Kernel > Restart` from the Jupyter menu.
#
# #### Markdown
#
# Markdown cells allow you to write fancy and simple comments: all of this is written in Markdown - double click on this cell to see the source. An introduction to Markdown syntax can be found [here](https://daringfireball.net/projects/markdown/syntax).
#
# As Markdown is translated to HTML upon displaying it also allows you to use pure HTML: more details are available [here](https://daringfireball.net/projects/markdown/syntax#html).
#
# Finally, you can also display simple $\LaTeX$ equations in Markdown thanks to `MathJax` support. For inline equations wrap your equation between `$` symbols; for display mode equations use `$$`.

# %% [markdown]
# ## 1. Acquiring Raw Text Data
#
# Now, let's get some text data! We'll start with the IMDB dataset, which contains movie reviews along with their classification into "positive" or "negative" sentiment. Run the code below to download the data from [HuggingFace's datasets hub](https://huggingface.co/datasets/imdb):

# %%
from datasets import load_dataset
import numpy as np

cache_dir = "./data_cache"

# The data is already divided into training and test sets.
# Load the training set:
train_dataset = load_dataset(
    "imdb", # name of the dataset collection
    split="train",  # train or test
    cache_dir=cache_dir,
)
print(f"Training dataset with {len(train_dataset)} instances loaded")

train_dataset = np.random.choice(train_dataset, 5000, replace=False)  # we'll only use a subset of the data in this lab so that the code runs quicker
# Out:
# Training dataset with 25000 instances loaded

# %% [markdown]
# We can access the documents in the dataset like elements in a list. For example, document 3 looks like this:

# %%
train_dataset[10]
# Out:
# {'text': "Like many of you I am a great fan of the real thing - the 1940s noir films - but Red Rock West was a real treat for all of us longing for the past. The term 'neo-noir' has been so often used inappropriately in the last ten years that it has lost its meaning and its impact. John Dahl's film on the other hand, truly deserved to be described as such. The casting is perfect all around and would have felt right at home with Tay Garnett or Jacques Tourneur. The plot is so tight that you are hooked within the first fifteen minutes. James M. Cain would have appreciated it. Many contemporary films leave me wondering why they don't make them like they used to, and I'm not even that old. Movies such as Red Rock West give us hope for the future while paying tribute to the past.",
#  'label': 1}

# %% [markdown]
# # 2. Regular Expressions
#
# ## 2.1 Search
#
# We'll start by trying out some regular expressions. Suppose we want to identify tweets where people discuss really loved about certain movies. We could start by looking for tweets that contain the word 'love'. A first step would be to find all occurrences of the word 'love'. Review the code below to see how we can do this:

# %%
import re  # Python regular expressions library

all_matches = []

for review in train_dataset:
    matches = re.findall('love', review['text'])
    if len(matches) == 0:
        continue
    else:
        all_matches.extend(matches)
    
print(len(all_matches))  # length of the list of matches
print(len(all_matches))  # length of the list of matches
for match in set(all_matches):  # Use a set to get a list of the unique matches
    print(match)
# Out:
# 1858
# 1858
# love

# %% [markdown]
# This has given us a list of matches in the variable `all_matches`, which all contain the string 'love', but not the sentences themselves.
# This isn't very useful, but we can do better if we define the right regular expression!
#
# Regular expressions define a pattern, rather than a specific string, allowing us to generalise our search and retrieve a many different strings that match the pattern.
# In Python, we differentiate a regular expression from a normal string by putting an 'r' character in front of the string.
#
# We can generalise our search by using a _disjunction_, which will match against any one of a set of characters. The disjunction is written inside square brackets.
#
# Let's try to retrieve instances of the word "love" followed by any letter. We can write a disjunction that matches any lower case letter as `[a-z]`:

# %%
all_matches = []

for review in train_dataset:
    matches = re.findall(r'love [a-z]', review['text'])
    if len(matches) == 0:
        continue
    else:
        all_matches.extend(matches)
    
print(len(all_matches))  # length of the list of matches
print(len(all_matches))  # length of the list of matches
for match in set(all_matches):  # Use a set to get a list of the unique matches
    print(match)
# Out:
# 964
# 964
# love l
# love a
# love t
# love h
# love k
# love p
# love s
# love v
# love o
# love z
# love y
# love f
# love i
# love b
# love m
# love w
# love g
# love c
# love j
# love e
# love n
# love r
# love d

# %% [markdown]
# Our current search only matches a single letter of the word after 'love'. The length of that following word is variable, so how can we write an expression to match the whole word?
#
# Here, we can use a special character, '\*', which will match against zero or more repetitions of the preceding regular expression. Let's try it out:

# %%
all_matches = []

for review in train_dataset:
    matches = re.findall(r'love [a-z]*', review['text'])
    if len(matches) == 0:
        continue
    else:
        all_matches.extend(matches)
    
print(len(all_matches))  # length of the list of matches
print(len(all_matches))  # length of the list of matches
for match in set(all_matches):  # Use a set to get a list of the unique matches
    print(match)
# Out:
# 1040
# 1040
# love lives
# love at
# love just
# love or
# love are
# love one
# love hate
# love begins
# love again
# love surprises
# love hip
# love blossoms
# love you
# love it
# love fling
# love any
# love magazine
# love must
# love old
# love animated
# love mattered
# love kenny
# love obsessed
# love porn
# love black
# love the
# love also
# love from
# love explosions
# love as
# love stories
# love destroying
# love laughing
# love redeems
# love an
# love reading
# love seems
# love special
# love himself
# love interest
# love dinosaurs
# love low
# love affair
# love rock
# love movies
# love back
# love when
# love their
# love bad
# love most
# love in
# love blooming
# love rival
# love zombie
# love these
# love vampire
# love a
# love amongst
# love struck
# love being
# love doubtfully
# love to
# love your
# love and
# love existing
# love set
# love both
# love creepy
# love foreign
# love means
# love those
# love motivates
# love without
# love trouble
# love is
# love cult
# love scene
# love me
# love like
# love scenes
# love because
# love every
# love all
# love interests
# love especially
# love while
# love within
# love come
# love good
# love with
# love mystery
# love life
# love crap
# love scenario
# love daytime
# love anyways
# love cartoons
# love he
# love were
# love how
# love new
# love them
# love non
# love towards
# love her
# love triangle
# love stupid
# love film
# love theme
# love his
# love completely
# love between
# love having
# love rod
# love but
# love along
# love him
# love on
# love if
# love so
# love comedy
# love amateur
# love isn
# love some
# love war
# love gone
# love seeing
# love this
# love that
# love my
# love fest
# love only
# love anything
# love horror
# love films
# love south
# love will
# love before
# love story
# love about
# love after
# love listening
# love full
# love triangled
# love thrown
# love someone
# love relation
# love of
# love pad
# love plot
# love more
# love for
# love beads
# love twist
# love killer
# love making
# love corny
# love police
# love buying
# love something
# love conquers
# love romantic
# love they
# love gory
# love not
# love
# love found
# love connection
# love watching
# love each
# love really
# love idealism

# %% [markdown]
# Let's say we only want to retrieve the word following 'love', not the string containing 'love ' itself.
# We can do this using parentheses to create _groups_ of characters, such as this: `([a-z]*)`. The resulting matches will be returned as tuples of groups, and any characters not inside parentheses will not be returned as part of any group. Try out the code below to see this, and note that the space character after 'love' is not returned in the matches.

# %%
all_matches = []

for review in train_dataset:
    matches = re.findall(r'(love) ([a-z]*)', review['text'])
    if len(matches) == 0:
        continue
    else:
        all_matches.extend(matches)
    
print(len(all_matches))  # length of the list of matches
print(len(all_matches))  # length of the list of matches
for match in set(all_matches):  # Use a set to get a list of the unique matches
    print(match) 

for match in set(all_matches):  # just print the following
    print(match[1])
# Out:
# 1040
# 1040
# ('love', 'rival')
# ('love', 'they')
# ('love', 'completely')
# ('love', 'war')
# ('love', 'my')
# ('love', 'creepy')
# ('love', 'each')
# ('love', 'crap')
# ('love', 'comedy')
# ('love', 'gone')
# ('love', 'theme')
# ('love', 'towards')
# ('love', 'killer')
# ('love', 'watching')
# ('love', 'back')
# ('love', 'any')
# ('love', 'as')
# ('love', 'isn')
# ('love', 'you')
# ('love', 'cult')
# ('love', 'having')
# ('love', 'those')
# ('love', 'begins')
# ('love', 'when')
# ('love', 'reading')
# ('love', 'himself')
# ('love', 'like')
# ('love', 'existing')
# ('love', 'corny')
# ('love', 'fest')
# ('love', 'mystery')
# ('love', 'amongst')
# ('love', 'trouble')
# ('love', 'connection')
# ('love', 'some')
# ('love', 'of')
# ('love', 'it')
# ('love', 'all')
# ('love', 'without')
# ('love', 'lives')
# ('love', 'stupid')
# ('love', 'between')
# ('love', 'seems')
# ('love', 'hip')
# ('love', 'he')
# ('love', 'every')
# ('love', 'scene')
# ('love', 'struck')
# ('love', 'animated')
# ('love', 'again')
# ('love', 'vampire')
# ('love', 'triangled')
# ('love', 'being')
# ('love', 'the')
# ('love', 'along')
# ('love', 'dinosaurs')
# ('love', 'someone')
# ('love', 'that')
# ('love', 'south')
# ('love', 'me')
# ('love', 'black')
# ('love', 'police')
# ('love', 'making')
# ('love', 'porn')
# ('love', 'beads')
# ('love', 'special')
# ('love', 'doubtfully')
# ('love', 'for')
# ('love', 'buying')
# ('love', 'mattered')
# ('love', 'interest')
# ('love', 'only')
# ('love', 'explosions')
# ('love', 'is')
# ('love', 'come')
# ('love', 'or')
# ('love', 'film')
# ('love', 'how')
# ('love', 'films')
# ('love', 'also')
# ('love', 'but')
# ('love', 'non')
# ('love', 'to')
# ('love', 'cartoons')
# ('love', 'not')
# ('love', 'his')
# ('love', 'if')
# ('love', 'plot')
# ('love', 'from')
# ('love', 'relation')
# ('love', 'most')
# ('love', 'foreign')
# ('love', 'rod')
# ('love', 'means')
# ('love', 'old')
# ('love', 'after')
# ('love', 'affair')
# ('love', 'found')
# ('love', 'your')
# ('love', 'fling')
# ('love', 'anyways')
# ('love', 'movies')
# ('love', 'blossoms')
# ('love', 'twist')
# ('love', 'while')
# ('love', 'so')
# ('love', 'set')
# ('love', 'gory')
# ('love', 'both')
# ('love', 'zombie')
# ('love', 'because')
# ('love', 'listening')
# ('love', 'full')
# ('love', 'their')
# ('love', 'surprises')
# ('love', 'them')
# ('love', 'her')
# ('love', 'must')
# ('love', 'pad')
# ('love', 'scenario')
# ('love', 'life')
# ('love', 'especially')
# ('love', 'magazine')
# ('love', 'conquers')
# ('love', 'amateur')
# ('love', 'these')
# ('love', 'daytime')
# ('love', 'in')
# ('love', 'a')
# ('love', 'romantic')
# ('love', 'horror')
# ('love', 'thrown')
# ('love', 'more')
# ('love', 'low')
# ('love', 'scenes')
# ('love', 'hate')
# ('love', 'rock')
# ('love', 'on')
# ('love', 'kenny')
# ('love', 'him')
# ('love', 'stories')
# ('love', 'obsessed')
# ('love', 'laughing')
# ('love', 'blooming')
# ('love', 'before')
# ('love', 'redeems')
# ('love', 'new')
# ('love', 'destroying')
# ('love', 'good')
# ('love', '')
# ('love', 'motivates')
# ('love', 'within')
# ('love', 'at')
# ('love', 'triangle')
# ('love', 'bad')
# ('love', 'will')
# ('love', 'were')
# ('love', 'with')
# ('love', 'story')
# ('love', 'this')
# ('love', 'idealism')
# ('love', 'are')
# ('love', 'an')
# ('love', 'really')
# ('love', 'just')
# ('love', 'one')
# ('love', 'and')
# ('love', 'something')
# ('love', 'anything')
# ('love', 'interests')
# ('love', 'about')
# ('love', 'seeing')
# rival
# they
# completely
# war
# my
# creepy
# each
# crap
# comedy
# gone
# theme
# towards
# killer
# watching
# back
# any
# as
# isn
# you
# cult
# having
# those
# begins
# when
# reading
# himself
# like
# existing
# corny
# fest
# mystery
# amongst
# trouble
# connection
# some
# of
# it
# all
# without
# lives
# stupid
# between
# seems
# hip
# he
# every
# scene
# struck
# animated
# again
# vampire
# triangled
# being
# the
# along
# dinosaurs
# someone
# that
# south
# me
# black
# police
# making
# porn
# beads
# special
# doubtfully
# for
# buying
# mattered
# interest
# only
# explosions
# is
# come
# or
# film
# how
# films
# also
# but
# non
# to
# cartoons
# not
# his
# if
# plot
# from
# relation
# most
# foreign
# rod
# means
# old
# after
# affair
# found
# your
# fling
# anyways
# movies
# blossoms
# twist
# while
# so
# set
# gory
# both
# zombie
# because
# listening
# full
# their
# surprises
# them
# her
# must
# pad
# scenario
# life
# especially
# magazine
# conquers
# amateur
# these
# daytime
# in
# a
# romantic
# horror
# thrown
# more
# low
# scenes
# hate
# rock
# on
# kenny
# him
# stories
# obsessed
# laughing
# blooming
# before
# redeems
# new
# destroying
# good
#
# motivates
# within
# at
# triangle
# bad
# will
# were
# with
# story
# this
# idealism
# are
# an
# really
# just
# one
# and
# something
# anything
# interests
# about
# seeing

# %% [markdown]
# Now, let's try to retrieve the preceding words as well. It would be better to match capital letters as well as lower case, which we can do with the disjunction `[a-zA-Z]`.
#
# TODO 1: complete the code below to retrieve only the words that precede and follow 'love', including capitalised and lower case words.

# %%
all_matches = []

for review in train_dataset:
    
    ### WRITE YOUR CODE HERE
    matches = re.findall(r"like [a-z]*", review['text'])
    ########
    
    if len(matches) == 0:
        continue
    else:
        all_matches.extend(matches)
    
print(len(all_matches))  # length of the list of matches
print(len(all_matches))  # length of the list of matches
for match in set(all_matches):  # Use a set to get a list of the unique matches
    print(match)
# Out:
# 3970
# 3970
# like donkeys
# like realism
# like dinosaur
# like sex
# like filmmaker
# like b
# like painting
# like buying
# like events
# like sh
# like fake
# like about
# like evolving
# like people
# like either
# like amateur
# like story
# like almost
# like complete
# like crap
# like go
# like letters
# like shedding
# like deterred
# like wearing
# like thoroughbred
# like dummies
# like action
# like walnuts
# like was
# like said
# like which
# like puritans
# like they
# like anyone
# like college
# like malaria
# like pre
# like musicals
# like reading
# like sailors
# like casting
# like shark
# like high
# like than
# like snakes
# like us
# like statues
# like panel
# like by
# like jousting
# like special
# like children
# like game
# like dimension
# like coffee
# like pathetic
# like reese
# like crazy
# like boarding
# like cutting
# like moi
# like contemplating
# like but
# like imagery
# like packaged
# like quiet
# like when
# like at
# like survivor
# like hitting
# like anti
# like home
# like already
# like quality
# like out
# like members
# like soundstage
# like boxing
# like being
# like skating
# like reality
# like dreams
# like whoever
# like spenny
# like ask
# like pure
# like football
# like inciteful
# like cleaning
# like two
# like grumping
# like quirky
# like glue
# like potato
# like that
# like superman
# like slasher
# like movie
# like writing
# like ever
# like random
# like device
# like six
# like justice
# like teen
# like continuity
# like star
# like brain
# like morons
# like glee
# like now
# like anywhere
# like gay
# like screen
# like punk
# like forrests
# like history
# like fire
# like style
# like smiling
# like marriage
# like toilet
# like miners
# like getting
# like universal
# like say
# like somebody
# like way
# like much
# like cr
# like mine
# like wartime
# like yours
# like them
# like later
# like exercises
# like chip
# like soap
# like hours
# like massacre
# like father
# like virgin
# like all
# like headless
# like gordon
# like quite
# like him
# like war
# like rock
# like wind
# like scrappy
# like low
# like oppressive
# like loads
# like well
# like sharing
# like others
# like hell
# like such
# like friends
# like westerns
# like zombies
# like play
# like someone
# like many
# like communicating
# like despite
# like porno
# like whether
# like she
# like
# like few
# like necessary
# like revisiting
# like dignity
# like pushing
# like this
# like total
# like another
# like stories
# like more
# like gambling
# like cheesed
# like hotel
# like fools
# like erm
# like cold
# like clinging
# like life
# like methods
# like slow
# like ages
# like eye
# like poses
# like serene
# like web
# like minds
# like bees
# like soft
# like myself
# like aliens
# like open
# like adults
# like movies
# like vinegar
# like cheap
# like twice
# like human
# like garbage
# like dogs
# like chalk
# like howard
# like closeted
# like these
# like anything
# like underground
# like filler
# like very
# like one
# like our
# like crimson
# like wild
# like large
# like pro
# like stupid
# like bang
# like abuse
# like never
# like so
# like would
# like with
# like face
# like last
# like actor
# like coop
# like mines
# like supernatural
# like plot
# like dinosaurs
# like screeching
# like fighting
# like gangster
# like ketchup
# like then
# like me
# like active
# like appear
# like or
# like insertion
# like we
# like charm
# like night
# like saints
# like nothing
# like noting
# like criminal
# like monster
# like looking
# like great
# like what
# like leprosy
# like caricatures
# like car
# like costume
# like her
# like part
# like several
# like use
# like were
# like puzzle
# like first
# like excitement
# like honoring
# like rant
# like stuntmen
# like other
# like woman
# like stuff
# like thrillers
# like setting
# like too
# like power
# like creature
# like atmosphere
# like moths
# like celebrity
# like smashing
# like playing
# like simplistic
# like brothers
# like splashy
# like he
# like occasional
# like backup
# like vision
# like each
# like serial
# like eyelids
# like in
# like real
# like monsters
# like drama
# like country
# like the
# like trainspotting
# like noise
# like wedding
# like flies
# like himself
# like mobile
# like mesmerized
# like humans
# like killing
# like not
# like beauty
# like approach
# like drugs
# like mental
# like lunatic
# like women
# like if
# like upbeat
# like voodoo
# like adventures
# like common
# like feel
# like comparing
# like girls
# like excessive
# like character
# like there
# like everyone
# like hypodermic
# like teddy
# like pieces
# like jazz
# like will
# like both
# like ending
# like gods
# like friend
# like film
# like rats
# like terrible
# like slowing
# like having
# like some
# like my
# like raptors
# like humor
# like candies
# like wasted
# like innocence
# like clips
# like cashback
# like riding
# like robots
# like uncritical
# like stacking
# like wrist
# like things
# like teaching
# like seeing
# like laughing
# like shrimp
# like sequences
# like animation
# like are
# like content
# like lesbian
# like band
# like loincloth
# like water
# like lazy
# like assurance
# like tommy
# like fart
# like have
# like sin
# like i
# like back
# like dance
# like twilight
# like watch
# like good
# like right
# like half
# like throwing
# like drive
# like an
# like young
# like teenagers
# like its
# like filmed
# like doing
# like pretty
# like films
# like practically
# like those
# like cigarettes
# like no
# like vegetarianism
# like assault
# like here
# like drunken
# like police
# like horror
# like once
# like something
# like avant
# like plain
# like bulls
# like over
# like spandex
# like because
# like everything
# like killers
# like sexual
# like attraction
# like look
# like their
# like director
# like creatures
# like photography
# like big
# like using
# like learned
# like bad
# like magnolia
# like improv
# like sound
# like trying
# like yelling
# like saying
# like somewhere
# like on
# like documentaries
# like cool
# like flashing
# like dancing
# like burning
# like state
# like cure
# like assistant
# like his
# like time
# like grown
# like how
# like ol
# like hero
# like eacb
# like powers
# like scenes
# like chimeric
# like vehicle
# like black
# like cheesy
# like finding
# like today
# like gore
# like you
# like watching
# like is
# like gory
# like original
# like mature
# like organizations
# like technologies
# like to
# like who
# like just
# like manager
# like forget
# like non
# like quibbling
# like contemporary
# like any
# like paid
# like white
# like old
# like chocolate
# like fantasy
# like double
# like personally
# like better
# like biopics
# like buddies
# like before
# like crucification
# like for
# like raw
# like complex
# like and
# like thorns
# like ah
# like magic
# like most
# like apes
# like simpler
# like every
# like taking
# like someones
# like thousands
# like watered
# like it
# like fifty
# like peanut
# like rabid
# like years
# like vampires
# like as
# like ben
# like expressed
# like your
# like classic
# like bursting
# like extraneous
# like narrative
# like tired
# like lion
# like helping
# like fight
# like tunes
# like normal
# like adapting
# like mohanlal
# like molasses
# like fox
# like safe
# like authority
# like after
# like manner
# like wine
# like demon
# like sci
# like making
# like a
# like shooting
# like herself
# like haze
# like jean
# like music
# like bloody
# like did
# like violence
# like little
# like mindless
# like of
# like ways
# like cheese

# %% [markdown]
# This is starting to look more useful, but we still want to retrieve whole sentences.
#
# Sentences in English are usually demarcated by punctuation, so let's use the following punctuation marks to identify sentence boundaries: '.', '!', '?'. Those punctuation marks are special characters when used in regular expressions, so to force Python to interpret them literally, we need to put the escape character '\\' in front of them.
#
# Now, we can write a disjunction that matches against the punctuation like this: `[\.\!\?]`.
#
# So far, we have assumed the text consists only of letters. Can you think of any characters we have excluded here?
#
# A better way to find all matches would be to use _negation_ to match against any character _except_ the punctuation marks that bound the sentences. A negation will match any character except those specified, which we can write like this: `[^\.\!\?]`, where the '^' indicates the negation.
#
#
# TODO 2: Retrieve whole sentences containing 'love'. To do this, modify our previous expression by using negation to match all of the characters except '.', '!', and '?'.

# %%
all_matches = []

for review in train_dataset:
    
    ### WRITE YOUR CODE HERE
    matches = re.findall(r'love [^\.\!\?]*', review['text'])
    ########
    
    if len(matches) == 0:
        continue
    else:
        all_matches.extend(matches)
    
print(len(all_matches))  # length of the list of matches
for match in set(all_matches):  # Use a set to get a list of the unique matches
    print(match)
# Out:
# 1005
# love blossoms, the first whispers, touchings
# love for studying history and the highest marks I got in our school's public exams
# love a mirage
# love corny romances and give them plenty of space but really---this is unbelievable
# love interest for Flynn v
# love to star in his movie
# love interest would not recognize Simon, because he has a half mask on
# love foreign movies
# love of all things tenacious, LAUGH
# love in all forms, native folk in their Parisian modes, and tourists interacting with the great city
# love it if you love 70's schlock
# love to "wrestle" and Scott tells Billy that he is "still sore from last night," among other things
# love to see the film again, I only saw it once in a little viewing theatre in Soho
# love laughing during horror movies (Return of the Living Dead 2, Evil Dead), but I don't know if we were supposed to be laughing here
# love story about two cons
# love with Lucas despite all she knows made me realise this show would just go there and not apologise for it
# love of her life getting smushed
# love Jamie Foxx, and I think he's really funny, and I thought he was funny in this movie
# love Jeremy Jordan
# love story seems to play a much too large role for a horror film (though this has a valid plot reason later on)
# love story into a crazy-Chinese-musical-in-Paris-with-Barbet-Schroeder into a social commentary into a terror comedy into a humble monologue
# love Billy Crystal, my wife loves Julia Roberts and everyone we talked to said they loved it
# love Dan Seymour's acting -- he usually plays some plump foreign sultan or police chief and appeared in Casablanca and many great pictures
# love film and are not lovers of the standard Hollywood epic
# love & hate for each other
# love and later married Jimmy
# love (my Soulmate) and although I had the experience to meet him when I had least expecting it, I wasn't ready for that kind of emotional relationship
# love and of his feeling about Paris as viewed through the huge backdrops of some of France's most Impressionist painters
# love in an old lady
# love for all things
# love with shots of them leaping through the air in slow motion, Six Million Dollar Man style, toward our heroes when they attack
# love found and lost
# love for her country
# love Lion King, you need this movie
# love story, or a drama
# love the music performances, the breakdancing makes me wanna spin, RAMO makes me wanna throw a piece
# love Eddie Izzard
# love interest
# love dinosaurs
# love in a cinema reel room - a whore having sex with a minor she barely knows
# love to see both of these two in other movies
# love listening to it
# love story is a little thin on the ground, but I'd say that's probably for the best, as this romantic comedy has the emphasis firmly on "comedy", and in any case it stretches the bounds of credibility just a little more than I like most rom com's to do
# love with decades from now
# love movies and try to give them the benefit of the doubt, but this one was up there on my lame list at number 2
# love to see the first version released in the U
# love to see the script as the first 40 mins was mostly annoying girly giggles and bad music, there was absolutely no character development
# love for theater, expression, vivid colors, humor and tragedy, makes this a great ride on the roller-coaster of Japanese cinema as well as theater
# love with Sandra but does not know how to deal with these emotions, and his tears after being expelled from the group, or his shuddering when he is given a hug, and his attachment to the mute young boy who in many ways reminded Todd of himself, and what he could have been if not for his selection to be a soldier
# love of color, motion and music might produce intelligent entertainment
# love to know
# love story involved which doesn't have anything to do with anything
# love how the dynamics between the three of them play out
# love the hero
# love in a motel room)
# love story between them
# love story, whose gloss of chess might make it appear cerebral
# love with his character right away
# love story about two young exotic lovers in ancient Egypt if played by the typical 300 pound over 40 tenor and soprano with the vocal equipment to sing the glorious music properly
# love Lucy
# love how he is revealed at the end - it would be too unresolved any other way
# love interest Peggy Lipton, and she looks old enough to have grown-up kids
# love theme was beautiful and tragic
# love that they just strongly believe they are and after a tragedy or so occurs, will believe it for the rest of their lives
# love Montana scenery and fly fishing you will find some value in this film just don't expect a story
# love with Odette because she looks like a Botticelli's woman
# love this film as well
# love every one of these performers, and it is a shame that, as an ensemble they achieve no more chemistry and no better result than The Bride Came C
# love and life before war brought terror and bloodshed to every doorstep
# love watching "Sabrina, the Teenage Witch" Friday nights on ABC's TGIF
# love it (ie
# love or money or both, but that is what makes this pilot even more intriguing
# love 'em
# love this movie, hell even my mom liked it
# love when the hero's ruthlessness touched the roof top
# love of the Horror genre
# love is here to stay
# love interest holds up the family values and E
# love for theater, cinema, musicals and the like would be annoyed
# love in Paris are all unique, but some of them, as expected, stand out
# love to see what these guys could do with the budgets, time and respect afforded to the likes of Yuen Woo-ping and Corey Yuen Kuei
# love Nicole Kidman, I decided to rent it last night
# love with a much younger woman, again
# love the acting, I felt it's themes were forced
# love like that, in 2 seconds WHATEVER I'd be more concerned with saving my own ass then getting some
# love it, I wanna own this movie
# love that but let me tell you girls something
# love for and passion about movies like this one
# love so things get even more complicated for him
# love Adult Swims shows
# love the depiction of the 30s and 40s in film
# love from their life, some try drink the pain away, some jump off buildings or bridges, some feel guilty and others feel so much agony it makes them so sick they collapse - physically
# love about this show is that it follows the lives of modern witches and it's a blast to experience their everyday love, humor and adventure
# love with her image, the more she falls in love with their admiration and the control she has over the gaze
# love them because vampires are just cool in movies
# love a monster you'll cry for Magnus Pym, the spy who betrays everyone - notably his country, his friends and family - a man who has also been manipulated and moulded since childhood by those same people
# love interest, resembled a ray of sunshine on the screen
# love to see more of these characters and I always wonder what became of them
# love and why
# love doubtfully mixed with treason
# love making, (nothing is ever seen, but the effect is wonderful
# love means more then words
# love for that special place and depict situations in the lives of its denizens and visitors
# love these kids so much, and it's apparent in every episode
# love with Francois, but he is smitten with Floriane, who seems to return his affections, although he is by no means her only male admirer
# love it for what it is
# love with a unseen pen pal
# love war so much
# love only to have it come back in the face of tragedy
# love special effects and witnessing new technologies that make science fiction seem real
# love how Hoffman is clearly the dominant brother and shamelessly picks on his younger brother even now that they're middle-aged men; and yet despite this, it is clear how Finney's father favours Hawke's younger, weaker brother
# love and getting mixed up w/ a vicious pimp
# love it so much
# love with her, but chooses to take the high road and stay with her husband
# love with a stud named Richard, who just happens to be married to a blues singer
# love not by romance but by brute force, as well as a funny twist on Roman gladiatorial combat, two comedic sketches that long predate such spoofs as Mel Brooks' "History of the World: Part I"
# love watching cartoons, still do
# love him Loretta
# love and friendship, and that makes it easy for faux friends to mislead her into making false statements
# love is the multiple interpretations present in the film
# love in the city regarded in popular culture as the quintessential romantic capital of the world
# love story comprised of beauty, youth and wealth
# love conquers all" philosophy of the 70s sitcom "Bridget Loves Bernie
# love at a Paris jail has the same quirky nature as his film Les Triplettes de Belleville
# love of Christmastime
# love and danger
# love Julie Stiles movies, but this is an exception
# love with Sissy, thumbs or not
# love the violence, blood and guts scenes, and the absolutely unnecessary sex scenes and boob shots
# love triangle -- or make a four-cornered-love, Japanese occupation, rebellion, American as lord), its presentation is something cool, especially it uses it original language -- bisaya for the Filipino, nipongo for the Japanese and English for the American
# love along the way; she emerges battered but victorious, and strong
# love and our families and their stories endure throughout generations of time
# love to see her work more with children, especially child actors
# love with Ann and/or Harris
# love interest Bob Townsend, the supporting cast is uniformly strong
# love from life or circumstances
# love with Gillian
# love buying those cheap, lousy DVD's from Alpha Video
# love with the "hunk"
# love horror porn stuff like Hostel (Which some reviewers claimed this was like, but obviously they only thought so cause Roger Bart was in this and Hostel 2)
# love the voice-overs
# love any movie with Robert Downey Jr
# love Vincent Price when he's out for revenge
# love it when authority is challenged and defeated
# love with fighting with each other
# love watching the shows, and we don't mind the re-runs either
# love when out of nowhere this giant hand came at them, and they reacted instinctively, defending themselves and biting the guy
# love Diana Rigg and I could see the pain of Lady Dedlock, even through the expected arrogance of the aristocracy
# love at first glance, the true love that one feels in his guts
# love story in the poem
# love to watch this movie a lot because of all the scary scenes about the raptors
# love for Anansa, and conscious of his own inability to find love, he agrees to take David up in his helicopter to help search for Anansa
# love this
# love and drug stories
# love Michael Keaton anyhow
# love each other
# love story with cinematography that recorded the love between "Harlan" and Tobe in long, poetic and idyllic scenes
# love The 40 Year Old Virgin
# love - to what's inside, which is the truth, and is a learning of this truth
# love this, & what other film offers a music cameo by Chuck Berry
# love story for the soul
# love and death, the plays translation onto celluloid comes across as a slightly to the right blurb of social consciousness
# love triangle" with Ms
# love with Jack Holt (as Karl Von Austreim), who had moved to America with his German father and American mother
# love watching the rear passenger wheels of cars), cheesy clarinet stripper music, and one of the longest death scenes in movie history
# love the 1946 US version (also entitled `Postman')
# love to get a copy of it to view it again
# love to accept that he has not been fully invested in the relationship
# love story, a moral message, and a man tortured by his past
# love or hate, which is why I believe a lot of mix reviews and not that greatest success resulted when this film was released
# love with her and decides to get married in Vegas in a week's time
# love with the two of them is nothing short of ludicrous
# love struck by a pink lady, Stephanie
# love with Barbara Steele and suffer the consequences
# love affair sparkles as brightly as the City of Lights itself
# love and root for to live a happy life
# love affair, which is good reason why there was sparks when these two appeared in this film
# love affair between Max Mok and Fennie Yuen and one crisis they confront thanks to Lowell Lo's character
# love and being human
# love New York and i loved the cast
# love with her ninety something sugar daddy
# love it for all the wake-up romance advice for men, and men will love it for its spot-on father/son character study--one great little scene after another
# love cult 70's Sci-fi the way I do, or if you like movies such as "Repo Man" or "Buckaroo Bonzai" than you're going to love this one
# love with the most awesome brother cast from One Tree Hill
# love with Kevin Calhoun and gives a great supporting role
# love story which is very moving when it needs to be, though in the first bit of the movie it is a little slow
# love and desire to break this relation
# love scenes were forced and mechanical
# love -- as one of the best films out there, Hindi or otherwise
# love he feels for this little slave girl becomes entwined in the stupifying tradition that requires him to pass his art on only to a young man
# love and caring, about the life that we have but we miss it sometimes because of material stuff
# love interest for the evil man
# love horror movies that take place in the woods or in the desert or on a farm
# love is beautiful
# love scenes had some extra zing to them because Tracy and Young were having a torrid affair during the shooting of Man's Castle
# love obsessed young man who's abused hurt and humiliated by the object of his obsession to the point of losing everything he has only to find true love in the end under the most unusual circumstances
# love to have this on video
# love only once in a lifetime" and said although it is short of Jorge and unemployed and does not preclude the possibility that it is a "sadistic" sleeping in his shoulder in the cinema at the earliest opportunity
# love with two men - but Hitchcock brings it to us on a silver platter, with laughter and fear, with compassion and anguish
# love story but i wont say no more otherwise it gives too much away
# love come her way, it is a minor miracle
# love me a slow movie
# love Matthau's grumpy character--he's just the same as he always is, and yet also very different
# love interest of Kelly's character leaves much to be desired, (IMHO)
# love to his wife and how hard he finds it to sleep with another woman
# love to be told
# love to purchase this for my brother, yet there is no way I can find it anywhere
# love story is a joke, and the movie as a whole is just hard to follow
# love him too
# love and acceptance after grieving, all of which is dealt with extremely well
# love Fatal Fury
# love Brass Eye and Blue Jam)
# love them but I am equally as sure that no one could have no opinion on LOG
# love he never had
# love to see it again
# love with Susie
# love to give Kolchak a higher rating but the show quickly went from scary/suspenseful to silly
# love Larry as much as I do, you'll love this film that is all Larry, all hot, and all fleshed out
# love in Paris, I think the film would have suffered if any cog was removed
# love for Ann
# love gory movies
# love redeems Liliom
# love with Maggie (Carole Lombard), who's always there for him
# love films that question the media, and also films that take a hard look on how people are railroaded by the justice system
# love it or hate it
# love but in the later films, are either exasperating blockheads or pathetic misfits
# love the same things and that by laughing at themselves and the absurd rules of sharia law that maybe a change for the better isn't too far away
# love are The Big Lebowski, The Princess Bride, and Zoolander (that one only got me the second time around)
# love fling
# love on her own terms and independently, and, at last, as Rochester's true equal
# love triangle at the heart of the story
# love  along the way they have many adventures (although apparently not enough for Sabu
# love Elivra as I did in her late night movie hostess duties will love this movie - she is just plain cool - her car is great, and she is a bit of a Transylvanian Dolly Parton - she is so innocent and naive at times - and sexy all of the time - plus, more than a touch of Mae West -<br /><br />The sets are well done as well, and the comic cast is great, with Edie McClurg at her usual best - plus Sally Kellerman as Patty is hilarious
# love mattered
# love and what is to be moral
# love this show and I hope TV starts making more shows like this one
# love before destroying them, instead of immediately disregarding characters already beloved
# love with Harris and continues to be
# love how the movie was just so well done and it never gets boring
# love to see my original script again if anybody knows where it is
# love to see her doing some leading work soon
# love stories
# love his scenes with Grandad
# love me, you will do as I ask you"
# love porn stars
# love his son, despite their many arguments
# love blooming en route
# love to believe them, but on this evidence I'm not likely to
# love the obnoxious friend portrayed by Bernard Fresson, for example
# love Dario Argento's work from that period
# love of the movies
# love seeing him in films
# love with equity
# love conquers all, even disease
# love the original and will do my best not to let this movie ruin my opinion about it
# love triangle with Douglas's infinitely patient girlfriend (Florinda Bolkan)
# love New York and have visited many many times before and after September 11th
# love between the former nuptials while exacting revenge on the former colleagues for his termination
# love affair with her and destroy his perfect world with his family
# love back
# love story ever written
# love with him
# love stories I have ever seen
# love the story on why Paul wanted Peter Falk for the part
# love the choice of settings for the movie
# love the bright colors vs
# love will not last long
# love to know whether Mormons believe that this is an accurate portrayal
# love to the visual and the word with text by author Norman Maclean, and stunning camera work by Phillippe Rousselot (Serpent's Kiss, Reigne Margot)
# love with the two characters shortly after arresting them, letting them go free
# love it or hate it, one thing you can NEVER say about this film is that it is boring
# love with her, but in his own way
# love story, then I highly recommend renting "the Ladies' Man"
# love as well, and she is willing to risk a great deal for a man she just met
# love like that by the end of the movie
# love interest (later, of course, Zira in Planet of the Apes)
# love that they used C
# love story or a drama; it's a rolling in your seats comedy
# love this, should I ever find a copy of it
# love must have appealed to audiences saturated by constant TV coverage of the Vietnam War
# love comedy - even those unfamiliar with the language
# love story - Sarah Michelle Gellar cutting herself - and a creepy mirror<br /><br />OH AND UNDERWATER SEA ANIMALS
# love that overflows into the poetic
# love them car chases,and all the beautiful cars,and the clandestine midnight races
# love between the main character and another one was completely unnecessary and seemed to come from a Hollywood influence
# love Country music but I can stomach it
# love amongst the feeding hours
# love for one's partner, child, parent, for those who meant the world to us but are no longer around, love that needs rekindling, serendipitous love for that stranger as your eyes meet, or love that just is not meant to be
# love story that fuels the plot is uninteresting, the two ladies are the only ones with any acting ability, there's another group of musical stooges that are unfunny, unless you consider their attempts at being funny to be sadly buffoonish
# love the gloomy and depressing look of everything
# love for Giovanna), a month has passed when Bregana and his wife go to the carnival and Bregana persuades Gino to go `back home' to live and work with them again, as he is handy to have around
# love this film
# love to you
# love John Ritter and his character Paul Hennessey and the relationship he had with his children was the best part of the show
# love with an older guy, etc
# love is
# love story about two humans on faraway star
# love zombie films and even bad ones usually have something going for them but not this atrocity
# love in life, and it has been worth every effort along the way
# love destroying those Japanese cities over and over again, lots of times in battles with each other
# love to see another more current example of cg showy offy stuff
# love of the thriller
# love at your final moment is enough to accept one's leaving of this earth
# love being terrified, do what you must to get hold of and watch a copy of The Woman In Black
# love the giddily over-the-top performances of Al Pacino, Dustin Hoffman, Glenn Headly, Charlie Korsmo, Mandy Patinkin, James Caan, Dick Van Dyke, supporting villains
# love these "Diaper Baby" movies
# love that film
# love with her boyfriend and wants to marry him someday, but she's become so fond of the soldier
# love affair Phillip has with Mildred, you could still enjoy it after seeing the movie
# love the movie theater scene - the funniest "making out" moment in the history of film, I'd say
# love movies that make you think, but this movie was just a bunch of ideas thrown together and never really connected
# love anyways) and overall, well worth the money you spend on it
# love Jamie Foxx
# love those mice
# love this show, I do think it should have ended on the seventh season when Eric and Kelso leave
# love but I think is probably because of my very different sensibility from that of Sylvain Chomet
# love with his best friend
# love triangle is simply stunning if you have the oppurunity to see this magnificent film take it
# love and enjoy to see aerial battles among old-timers, then this is a picture for you
# love kenny hotz, and spenny rice has a charming side to him
# love story, yes, but what made it outstanding from the rest was that it was told in an entertaining, wholesome manner
# love with her)
# love story (kareena in the rain, behind me on my bike hmmmmmmm)
# love with Anna and she has to choose between a safe life or Charlie
# love story as real as it gets
# love comedy, this is probably a show for you
# love of showing male genitals), is perhaps THE most overrated European Marxist director - and they are thick on the ground
# love this game to death
# love Monte Carlo and thoroughly enjoyed this movie
# love and company of his wife, the Countess (Marion Leonard) in a more private way
# love Austen, then don't waste your time with this
# love with the family's daughter - the woman that sent the Christmas card
# love they did not have dramatic pauses were they went off and did a montage every 15 and then reunite in love again
# love it or you hate it" movies
# love of Fox's character (why is beyond me)
# love for granted and he withstood it for 7 years
# love hate relationship
# love with Stewart--and apparently in the witch's rule book, this is a definite NO, NO
# love this town and the world the we live in
# love Chinese/Asian cinema like myself
# love to praise a great movie and I'm not biased toward "male" movies
# love and bravado on the Lower East Side of New York City with the two leads being superstars in the making
# love for one another
# love and a time to die",his masterpiece,IMHO,and finally" Imitation of life"(1960)
# love isn't enough to keep our loved ones from hurting themselves
# love this film because it's so crazy and off the wall, that it beats the hell out of any stupid soap that they have on daytime television
# love to see more of her films
# love is discovered, it will take its prisoner anywhere to continue the journey
# love one under a blanket on cool a cool evening and watch, or better yet why not a double feature
# love is really like despite the obstacles John Norman (Kris Kristofferson) and Esther (Streisand) face
# love daytime soaps or despise them, this move pokes fun in all the right places
# love triangle
# love this movie because I grew up around harness racing
# love the songs once you have seen the show you can sing along as though you are part of the show singing and dancing
# love the interpretive potential it has
# love every hackneyed bit of it, every line of stilted dialogue, every bit of needless technobabble
# love with a heterosexual woman
# love story, about a couple overcoming various difficulties and antagonisms (often with physical threats or harms) to be together
# love of female-centred comedy
# love you" in a splatter flick
# love the whole world, but given that a human heart is very small in size, every human has that special place that he loves more than any other
# love of god and love of human in movie we cant find anything like that all we have is,some villain who is really bad and kills people whose clashes with his thoughts
# love with Katey when she played Peg on Married With Children
# love for sailor Bilge Smith (Randolph Scott), Bilge's dalliance with another woman, and an old schooner that Connie inherited from her father
# love the book and am a huge fan of his work, Stanley Kubrick's retelling of this story is far more compelling
# love that is revolves around the holiday season
# love the idea one can't change the past; it's a nice counterpoint to so many time-travelling movies which say otherwise  biological holocausts and the thin line between sanity and madness
# love interest after Paul passes
# love him
# love their characters and have a wonderful charisma between the two
# love triangle" as the woman's boyfriend is back in town visiting her for the season
# love of all that is holy, Do Not Watch This Movie
# love scenario is the one that works least well
# love (which is at least four tales too many in my estimation)
# love and get married
# love most about the show is that it kind of plays out like a great Anime
# love with another fellow cop
# love the Doodlebops
# love with from "Office Space" up to "Sex & the City")
# love Westerns
# love interest it gallops along, taking the splendid cast with it to the violent end
# love along the way, and belts out a lot of hit numbers, too
# love stories I strongly recommend this film-10/10
# love triangle of emotions
# love the movie
# love that sort of bickering, but I hate it, so I never got on the Moonlighting bandwagon
# love how they didn't make them scary, but cute and huggable
# love hip hop and I live for it but after seeing this movie every person with a little intelligence could see that this is not how someone is suppose to live
# love to Martina, the most beautiful girl in town
# love Paris, present company included, we are blinded by the fact that this movie SUCKS
# love in a "sister" who has come back to him in NYC, so he's left to his own devices when he befriends a painter (Alan Arkin, very very good here), and then is found out as a Nazi-in-hiding by a white supremacist newsletter, leading wackos to his apartment
# love from "Street Fighter"
# love of all things Cajun, please have the actors study the language, live amongst the people you are portraying and get an all around understanding of how they are before you go trying to act like them
# love a good sappy love story (and I'm a guy) but when I rented "Love Story" I prayed for the end to come as quickly and painlessly as possible and just the opposite for Ali McGraw's character
# love the theme music, it goes well with the film
# love for Mark and will wait for him
# love Kevin Spacey and I hear he's gonna do another film about the general
# love of my life
# love and an alchemist that he's employed and it's more greed and insanity that seems to be his problem than demonic possession (unfortunately)
# love and live life even though it will always be somewhat hopeless
# love if people in the US were less stereotypic and more accurate when they talk about this country
# love with her
# love to give this crap a 0
# love of the novel in order to make his film more frightening
# love story
# love of Sam for Muriel spans the many years they have known one another; they seem inseparable
# love to the Princess, answering her three questions at their first of three meetings
# love his acting as a guy who never gets an even break in life and winds up messing around with Shrimp, (Jumbo Size) and at the same time lots of gold bars
# love the music in the movie
# love this movie, even though I only have a dubbed-into-Japanese video version of it
# love crap horror movies, but this was too much
# love to see these guys branch out ala Marlon Wayans portrayal in Requiem to a Dream
# love with Rolf Saxon as Hudson Talbot
# love to watch a lot of this movie because the computer graphics seem a little fake but it's okay because once you get into the movie you hardly even notice what is going on and I think it's got a good ending even though I didn't really understand what was going on on my first couple viewings I figured it out over time and that's the important part
# love with a beautiful psychic and then, that beautiful psychic gets haunted by the ghost of the disgruntled dead bride who wants to keep her from stealing her boyfriendhe heit'll be hilarious
# love and compassion for his fellow soldier as he did disdain and irreverence for the establishment that was trying to kill him
# love a happy ending and this film gives a brilliant one with the truths of Red Sox slotted in
# love towards Nancy (before he kills her), is supposed to show his 'sensitive side'
# love to know more about how much he had to do with it, because it's an exceptionally clever variation on the sterile master/fertile servant tale - nearly an allegory of the entertainment industry, run by dried-up numskulls, but made into a vibrant world of art and play by an exploited underclass of nobodies and non-WASPs
# love of and affinity toward animals, citing the usual stuff about how he prefers them to humans because humans can be soooo mean
# love with it
# love Fanfan
# love you had a comedy about a horrific situation, and here the basis is a terrifying scenario which actually yields some very funny moments
# love Julian Sands and will at least attempt to watch anything he's in, but this movie nearly did me in
# love set in Paris
# love to be normal
# love having a movie I can watch with them where men have integrity and character
# love romantic comedies
# love just about every one of the shorts that they have made
# love a mix of both genres
# love good cinema, good music, good dance, great art
# love non-affair, the unrealistically silly war scenes and the abuse of the syrupy soundtrack in a film which avoided carefully all historical or political references (Stalinism, Nazism, Holocaust) only to end on a passing but nonetheless insulting to our sense of history endnote about "liberating Poland"
# love Isabelle Adjani - she's so foxy in this movie, it's almost unbelievable
# love of fly fishing and each other will tie them together forever
# love with the wrong woman
# love and behave violently; they take from the rich and sell to the misbegotten; they steal from everyone
# love the gangster genre and this is the weakest entry I've seen in recent years
# love were slightly, no no, completely retarded
# love for one another, and it comes through even when they simply look at each other over the breakfast table
# love and happiness
# love this, others will just find it very, very loud
# love of woodwork and New York City (Brooklyn in specific)
# love it 17 or so years after the first time I saw it, in fact I discovered that I had lost my copy of this and was very upset
# love is pretty touching and warm
# love killer Insects movies they are great fun to watch, I had to watch this movie as it was one of my Favourite horror books by Shaun Hutson
# love a lyric that includes the line: "If you want to send your sister in a frenzy, introduce her to Barry McKenzie
# love to spend the evening with him, he will treat him to all the wonderful Christmas food that this errand boy has probably never seen
# love is killed by another man
# love story goes nowhere, and is poorly done
# love for Fanfan
# love and the clean picket-fences painted white, the second act is started three years later, after young George (a young and unrecognisable William Holden, then aged 22) and Emily have fallen in love and intend to marry
# love interest, who, when she first appears, the wind actually blows through her hair
# love Heavy Metal, this is the Movie for you
# love for each other that makes this film powerful
# love but when spring comes along, she gets the shock of her life when she is placed one step lower on her pedestal that Ben has put her on
# love of the genre yet know not to take zombie movies too seriously
# love a good romance film, then you will love this movie
# love horror movies, but not all of them
# love the movie and recommend it to all who love one-liners and things that differ from the "normal"
# love Gus
# love with heartfelt sensitivity, never crossing over into maudlin excess even once
# love the Christmas special too with Tweety as Tiny Tim, it's cute
# love to watch Tess (the director), Dom and everyone else on the very small close personal set try to bang out this little trippy creepy film
# love full of slugs
# love the simplicity and I love the love
# love with Ms
# love it lol but i make sure I'm well out of the room before it comes on
# love me later" flicks
# love about 'Forbidden Planet' and yes, I certainly consider it a 'classic' science-fiction film for many reasons
# love George C
# love idealism and artsy experimentation
# love with Harris, but being 1953, he has redirected that homosexual desire for Harris to his good friend, Ann for he cannot admit to himself that he has a sexual craving for another man
# love this stuff
# love with and act in such a way that, in the real world, would drive anyone away
# love you
# love it
# love really classically beautiful actresses and appreciate them even more if they can act a little
# love an opening ending
# love good acting and drama, I would leave this one out
# love of the American people and the land
# love at first sight
# love existing beyond religious and racial differences
# love and passion and tears there is more than USA in the world and it's good :) really good
# love of frollo,not mentioning jehan (brother of frollo) not mentioning mother of Esmeralda (maybe it is OK,the storyline would have chopped much)they even not mentioned the real story
# love for beautiful details
# love for Paul Reiser who understands what it's like to be both a father and a son, as well as to have both laughter and tears as you move through life
# love with him, her, his wife and daughter, all the dance instructors and dance students
# love it
# love scenes are hilariously overblown-- the scene in which Sulia "heals" Terry is obviously intended to be a tender moment, but it's virtually impossible to not be thrown into spirals of giddy laughter by the sheer ludicrousness of it
# love is pronounced by the lovers, how quickly they kill the husband (there is no botched first attempt as in the U
# love beads and all night parties and evolved back into mainstream life, whatever that meant
# love explosions
# love because Alex had abused and battered her
# love me" number was criminal
# love affair with Court
# love to talk more in depth about the film for any one who wishes to send me an email
# love black comedies)
# love the way he tells the history, moving around all the roles inside the Yakuza's family, and making that we see the violence, like the only way they have to solve their problems
# love the soundtrack, especially the above mentioned Different but also Zap The World, Pufnstuf and even Jack Wild's touching If I Could
# love it along with the message that was being portrayed
# love - as is the case in this film
# love with a girl suffering from parasomnia, then it would have been a better movie
# love in all the right places dealing with girls and family
# love scene involving grocery items has to be seen, it cannot be described
# love for the first time
# love with her, leading to a definitely one-sided marriage, spent on a huge estate in Chicago (which appears to be surrounded by mountains
# love to see January Jones do an appearance
# love this actress
# love between two people obviously feeling a connection, but unable to quite vocalize it
# love to be
# love Michigan, a good story, or a decent thriller go check out "Hatred of a Minute
# love it now, as a 24 year old
# love and family
# love for each other was expressed completely by words
# love interest, who pays homage to The Big Lebowski (also starring Bridges) with his ever-present White Russian, one of my personal favorite drinks
# love story in the plot to make the film more marketable to a 1950's movie-going public
# love it so much, is it had the guts to never be black and white
# love with him and questions if Joe Strombel is right in his scoop
# love each other and be married
# love story that I do enjoy watching
# love her in Steve Martin's "Roxanne," 1987
# love at first sight with the luminous Juliette Binoche
# love to
# love of God, don't watch it
# love and other things in between
# love scene is particularly grating in this respect: an insult to the talents of the lead actors
# love this Hollywood teenage movies
# love the films creepy atmosphere like the whole it could happen here sort of situation makes it scary to think about
# love of the characters for one another
# love bad movies, and I love horror and I love new inventive movies
# love between the characters
# love fest that is, even with the superhero thing going, believable
# love rock n' roll
# love story" was good, but the horror aspect was quite bad
# love that we're truly alive
# love that he was looking for all of his life
# love that is honest and consistent in tone without being emotionally dishonest or sensationalist
# love to talk about but can't cause it would spoil it), and the image of Rosario Dawson as nothing more than an image, stayed with me
# love scene
# love his unusual goofy looks, complimented by that strange hairdo he sports in most of his movies
# love for people they don't deserve, then this is the movie for you
# love for Muriel, the mother that has sacrificed her life in order to keep the family together
# love that is portrayed in this cinema family is to be emulated and cherished
# love Michelle
# love with her, a bitter and resentful young man
# love them or I loathe them
# love scene between them and a gory autopsy to get a PG 12 and thus to attract the huge adolescent audience
# love story thrown in is laughable
# love to hear from fans
# love the newer episodes with CJ and Grandad - I also liked the storyline with Kate falling for the principal
# love for the blonde
# love is and blah blah some other nonsense
# love some Cole Porter just like the next person, but jeez, don't mess with the Shakespeare
# love something (mostly for being bold), for me it was only Gina Gershon cameo's scene
# love story in the woods just like Titanic was a love story on a boat
# love someone you can't love
# love one woman, sleeping (mostly in this very flat) with another, and running around Paris proposing marriage to yet a third, well, I suppose I can wish him the best of luck in the dog-eat-dog world he's chosen to create for himself
# love movies, and I'll watch any movie all the way through, just to give it a chance
# love films like Robert Wise's The Haunting (1963), but you also have a taste for late 1960s/early 1970s Spanish and Italian horror, you may love Blood Castle, as well
# love about this film
# love stories in this movie are totally wrong
# love like this one, I recommand you to read some independant comic books : Chester Brown, Joe Matt
# love stories, some of the stories really dragged on in this movie
# love to see this released on Video/DVD some time in the future
# love triangled threesome eventually wind up in France, with the Great War (World War I, in hindsight) complicating their lives considerably
# love animated movies
# love with their particular brand of cartooning that they label every movie starring spiky-haired, big-eyed characters as a work of art without even considering other more vital factors, such as the plot
# love the fact that nearly every character from the book is present here
# love with her along with Lee
# love Mira Sorvino (i even excuse her for that AT FIRST SIGHT crap)<br /><br />Q : Why were we only 8 people in the theater this saturday on the first week end of release
# love her" but he didn't
# love to act "immature
# love this steaming pile of mountain goat dung
# love story with 3 high points: the performance of Reese Witherspoon, who maintained her promises in the world of cinema, the beautiful cinematography by the "Old Lion" Freddie Francis and the fantastic score by James Newton Howard, which is really the soul of the movie
# love how we witness him from being a loner to actually learning to have emotion and after the kidnapping becoming a cold instrument of revenge
# love begins, but this one is like already doomed by the first one
# love with Kermit the Frog then the father doesn't want to hear it
# love cartoons
# love without possessiveness
# love police movies filled with action, shooting, chases etcetera
# love how he allows the audience to be totally themselves and unrestricted
# love in the prequel
# love or lack thereof, the pain, the confusion, the hope, the needs and escape mechanisms develop through minutes different rooms of the house and down to the street and eventually below
# love Saura's Flamenco, you'll want to see Iberia, but you'll be a bit disappointed
# love this show
# love interests with women at least 20 years his junior
# love vampire movies
# love with each other Amitabh is 65 and Tabu is 35
# love this show and my 11 year-old daughter and I LOVE watching it together
# love for documentaries, or either of the bands
# love story, was exactly what I was predicting in my mind
# love with a female hit-man prefigures the quirky crimedies that caught Hollywood by storm in the early 90's but the script is too convoluted for its own sake, the motivations are off and on the whole the story seems unsure of what exactly it's trying to be: a romantic comedy, a crime drama, a gangster saga etc
# love her
# love interest, and is good as the strapping island lad
# love especially the fight scene between Wu Ma and the tree demon tongue
# love Emma Roberts now, too
# love for the first time, or at least think they are
# love gone wrong story
# love as Jack Bauer on '24' once again playsJack
# love triangle its conventionally structured script would suggest
# love Meg Ryan and she is as sweet as ever in this wonderful movie
# love come back in although it's hard, there lies the true happiness
# love is the ongoing surprises
# love story where both discover each other
# love all types of films, especially horror
# love the most as well as one other that I have also reviewed
# love Shark Attack 3, I love Bad Taste, they are HILARIOUS
# love story begins
# love conquers all
# love of the Captain but they came from different classes
# love and marry, husband is supposedly killed by a family friend who wants their family fortune, woman remarries and surprise surprise husband no
# love pad quite well, and found a few outlets, since he<br /><br />has electricity
# love each other, become a vital community
# love affair where a ravenous wife complains to a morally weak man that her husband is worthless and mean to her
# love for homage
# love and sabotage on and off the Atlantic platform
# love watching early colour films - you mean those 40s clothes weren't all grey
# love story and instead I got some boring student project about some idiot who has to find the strength and courage to marry his boyfriend while his annoying Christian brother tried to destroy it all
# love and friendship can bring, etc
# love affair with Maria) with the expected consequences
# love rod that he keeps out flapping in stride
# love of a woman, Natalie Dabrova (Evelyn Brent)
# love story underpinned by the politics mid 20th century / pre-WWII India, where the British and their modern ways are bad and the primitive but honest and true Indians are good
# love all six of the Stooges (Curly, Shemp, Moe, Larry, Joe, and Curly Joe)
# love really is, action not emotion
# love with one of the three, but doesn't have the chance to tell him before the three sail off to war
# love the episode when I think her name is DD
# love with mistress Leonor Watling) is ready to divorce his wife Miranda Richardson until she confides she has terminal leukemia, Juliette Binouche confronts agony about her son's fantasies and loss in Place des Victoires with the help of a mythical cowboy Willem Defoe, Sara Martins and Nick Nolte and Ludivine Sagnier display a keen tale of mistaken ideas in Parc Monceau, Fanny Ardant and Bob Hoskins 'play out' a strange relationship in Pigalle, Melchior Beslon plays a young blind man to actress Natalie Portman in learning how to see in Faubourg Saint-Denis, vampire love between Elijah Wood and Olga Kurylenko in Quartier de la Madeleine, Maggie Gyllenhaal is an ex-patriot actress stung out on drugs in Quartier des Enfants Rouges, and Margo Martindale is a visiting tourist letter carrier trying desperately to speak the French she has studied for her life's trip in a tenderly hilarious 14ème Arrondissement
# love his sensitivity, his ability to cry in front of them
# love the snow scenes and scenes of stores and the church because I've been there
# love the Satan Pit
# love the Bourne trilogy
# love to see films that make everything look real and is not phony or disbelievable in any way
# love to an actress you kinda grew up with
# love story was a part that i really enjoyed in the movie also
# love scenes in clothes warehouse are second to none
# love and almost instantly
# love with the wife of the man he killed, tries desperately to save her father without giving himself away
# love the story and the things that goes on in the film
# love a la Freddy Kruegar); Trampa also attempts to add something different to the standard template
# love a good meandering character study as much as the next indie buff
# love John, Neha Dhupia has a small role in this film and plays it well
# love that ol' hunk-o-brutal Carel Struycken, as any self-respecting Dutchman should
# love and swim and get stuck in grottos and one of them has a depressed mother and another has no mother and they talk and walk and swim and have sex and get drunk and then break up and someone goes to the hospital for eight days and then gets out and there is a lot of fast forward and rewind and there are long pensive shots of one of them looking into space or just sitting and doing nothing
# love seems to be present
# love movies like this, the whole "A guy meets an eccentric woman who he likes, but he happens to already be involved with someone, who not right for him
# love interest there is and Nabors does his umpteenth Gomer Pyle impression as faithful mechanic/best friend Lugs
# love story in it felt alittle rushed and they didn't explain things properly but it didn't ruin any part of the viewing experience
# love the story here of going to the extreme to obtain revenge because most movies usually just want revenge but really never go too far where as this movie they show how far a man can go to do what he feels is right
# love south park you'll love this
# love Henry James books and Washington Square was no exception
# love with Lisa," I almost screamed at the screen
# love in such short time
# love them or dislike them, and still feel the emotional impact of the movie
# love of God, pretend this film was NEVER made
# love the fresh prince
# love to watch it with friends because of the swearing and sex jokes
# love for cars, would never learn to drive and would die in a car crash
# love and hurt, never striking a false note
# love to see more of in the HK mainstream
# love 'Member of the Wedding,' I find Julie Harris to be a jumbo-drag and an adenoidal, scenery-chomping thespian in everything she's been in
# love also rings true in many ways
# love of her life and experienced her life's greatest tragedy
# love him, you give the guy his space, go home, and try that scenic getaway next year
# love them both but 2pac and Lil Kim DID get embarrassed in this movie for sure
# love how not-stereotypical benny is
# love rival Tarzan, hunter Harry Holt (Neil Hamilton) returns to the jungle to have another bash at winning the brunette babe's heart
# love affair, if I may say so
# love this movie
# love both of these shows a whole lot
# ...
# love a good "bad" movie
# love that will NOT be admitted to, a very blatant comedy, and a very well put together voice acting cast (both Japanese and American translation)
# love all the characters in this film as well
# love of his family, but he recaptures it in the affection of his employees, and you feel a heartwarming glow when, in the bitter cold of a Christmas Eve snowstorm, he finds companionship in a freckle-faced young errand-boy (Charles Smith)
# love this film, & even clearer why they do
# love this movie like no other
# love surprises
# love with his daughter Sally, Frances Dee
# love with Jimmy's good friend the happy go lucky Fred despite his obnoxious antics towards her
# love you, Riff Randell
# love her and admire her at the same time, partly because of her role, partly because of her magnetic and positive personality
# love again
# love lives,jobs etc
# love interest Kate where she drunkenly says "I love creepy boys," perhaps asking the audience to do the same
# love scenes, especially when your main actress won't do any nudity and you have to rely extensively on a body double
# love to see it as a weekly series
# love story, the Salem witch trials, Spock as a human, the desperation of being left in total isolation
# love it as we loved "A special day"
# love the opening shot of Pittsburgh (not Baltimore, as another user commented)
# love Anne Rice
# love for all
# love with PomPom
# love with himself, and then has to promote a chicken fast food chain and while doing this, doesn't love himself
# love Ann Marie but all he wanted was someone that he could control
# love about this movie is that it so stretches the envelope of adventure movie to come out of Hong Kong
# love and decide to run away but Pooja tells Jimmy that she can't do this as she owes a debt to Lakhan Singh, who is also known as Bhaiyyaji
# love more than one person, and this director is not one of them
# love stories it would have worked
# love interest Megha who he is ready to do anything for
# love relation between Antoine (Depardieu) and Cécile (Deneuve)
# love the person in the mirror
# love the show it's great for kids and adults, OK, everybody
# love "Pushing Daisies" and look forward to Wednesday nights just to watch it, then for the next week I watch it a few more times on my DVR
# love for drugs and a sense of entitlement coupled with a distaste for authority, values and "the establishment" is the world that the film captures
# love with the characters and the heart-warming story
# love connection between Molly and Bolt wasn't necessary to plot, I found "Life Stinks" to be one of Mel Brooks' observant films where prior to being a comedy, it shows a tender side compared to his slapstick work such as Blazing Saddles, Young Frankenstein, or Spaceballs for the matter, to show what it's like having something valuable before losing it the next day or on the other hand making a stupid bet like all rich people do when they don't know what to do with their money
# love and just how important life is
# love with a charming gamine Lise Bourvier
# love for medical horror
# love and life of one was lost
# love with horses and their world
# love in a busy street
# love him he'll drive you crazy because they know they can
# love affair
# love to live and the villagers are all wonderful people most viewers would love to have as neighbors
# love is and this movie could be a melodrama in a sense
# love this movie also find that aspect of the film darkly comical
# love the acting
# love the mindless action flick with hot chicks as much as the next guy
# love with the idea of babies and marriage, pinning her hopes on women's magazines until she spies super-bait in the form of sleek bachelor Cary Grant
# love and trying to escape the authority of the future to live a peaceful life in the past
# love the care bears, and their messege
# love scenes in the desert are simply beautiful, it is hard to imagine this kind of approach from a film of our times
# love and support of Miss Riley is evident as well
# love for Joan Fontaine
# love dinosaurs doesn't mean you can just slap together any old story and show it to the children
# love affair with the lead actor which seems to spring out of nowhere and has them making out on a beach and falling in love within a couple of hours of meeting one another
# love and obsession, rather than the venerated board game and after drawing me in gradually over the first half hour, became totally compelling
# love any Irish movie, or almost any movie about Ireland, and any film that has the late Irish actor Donal McCann in it gets my vote
# love the boat scene where the English guy and his wife are talking about all the stars and it's midday and sunny
# love with her for so long
# love movies that give us a glimpse into the seedy underworld, but this film couldn't decide if it was a bad horror film or an even worse serious commentary on the horrors of addiction
# love of all that is holy, if you cherish your sanity- never view this movie
# love with his co-worker Hannah (perky Anna Faris)
# love them i even enjoy watching the show
# love the backwoods feel of this movie
# love to hate
# love it so much that I've memorized most of the script (especially the scene in the storage unit when Jerry Lee breaks wind) and even with the script in my head I still like to watch it for Jerry Lee, that German Shepherd is hysterical and really is put to the test to see who's smarter
# love plot is more embarrassing and ridiculous than in Hong Kong action movies
# love with US Army volunteer nurse Rose Duffy, Gladys George
# love for her husband
# love from a fresh angle
# love Elvira and I like this movie
# love and trust
# love you" to the other while they were alive
# love with Hal Hartley's directing many years ago - I found that these films could make me laugh in an place that is rarely entertained
# love to both of the girls
# love thrown in somewhere, then i must recommend this film as a must see
# love on nose, the spray of sweat from the mauled head, the heroic music signaling the long-awaited apotheosis of the victor
# love Quadrophenia like everyone else) proved enough to get me away from the beer and partying
# love is enjoyable to watch
# love in Warters' movies
# love the "Ladies' Man" sketch on SNL
# love with Apollonia (Appolonia Kotero)
# love for anyone but herself
# love stories
# love movies about nature
# love scene an almost cheesy sensibility
# love watching women like these on screen
# love to know the backstory behind all this backbiting
# love reading INTELLIGENT and INSIGHTFUL commentary
# love it and even responsible to spread favorable reviews across the countries' borders
# love begins to render the beauty of the moment in words, "The way you cut through space
# love and not just this part time lover status that he seems to perpetrate with all of the floozies who inhabit his bed for a night or two
# love anything Hollywood made in the 1930s, this one is one you can easily skip
# love interest are already under the car
# love your children, you won't expose them to this
# love a scene where a guitar shoots lazers and vaporizes headbangers in the crowd
# love with Dane's girlfriend was like
# love that Tom Barman has for Antwerp and urban lifestyle
# love this picture
# love how everyone points out obvious observations such as the "5 cent baby attached to a fish pole" hahaha, well, yes
# love and intelligence, be smart and all
# love with
# love that I think should be an absolute romantic classic up there with Casablanca and Breakfast at Tiffany's
# love each other without knowing it
# love to boys
# love is in itself doomed to failure, but people (especially men, I think) should work on themselves and try to overcome the ruling morals before and not through practicing liberated love
# love the type of humor in this film, it just makes me laugh so hard
# love and devotion in Philip all those years that he was in love with her but choose to abuse him and have affairs with man who were just like her, cold unfeeling and selfish
# love all of their future military style, but I was impressed with the effort
# love trouble drama about lost and sadly people
# love with his work that instead of cutting the movie down to a pace that kept your attention, he added all of the footage he had shot together
# love motivates him to make amends and fight for a better life
# love the Mick's last line before he goes out for his dose of lead poisoning
# love and passion, but I couldn't see it in this version
# love affair with his deputy director,Clyde Tolson( If you want to know more about that subject, I suggest seeing the film Citizen Cohn)
# love is that not everything is a punchline
# love animated films and a little of this minimalistic UPA style goes a very, very long way and you can't seriously consider them great works of art--just very, very quickly made cartoons
# love again without this film flitting across my minds eye
# love bad monster movies
# love with the mother and is a substitute father for the two girls
# love Zombie-Movies and I love amateur-productions
# love so bitter-sweet
# love old-fashioned musical comedies
# love to write some more but am on quite a time limit
# love while they hustle their bodies on the street
# love this movie but it's one of the worst of the 70's
# love to be able to meet the writer so I could just ask him what the real meaning was to it all
# love this movie, but the music at all the alumni gatherings is just stupid
# love so much, such as seen in Yasujiro Ozu pictures -- the title credits even begin in the same way, with the Japanese letters (characters) in red against neutral color burlap material
# love to show around and they even canceled Frollo's love
# love so, instead of following in his footsteps, she ran away to the big city in search of something to make her feel like her life is worth living
# love to tackle (the humanity of terrorism - Four Lions) that he isn't going to cock that up, wasting the opportunity to make a statement about the farce of mainstream ignorance and opinion on this emotive and heavily spun phenomena
# love completely, but broke up at last and promoted a deadly agony
# love in the city of lights
# love American wrestling this film is a must, but be ready to see Henry Winkler as you have never seen him before
# love to read it
# love how they configured historical legends to fit into this anime, it was amazing and just made me want to research a whole lot more
# love them
# love about this movie, is that it perfectly captures the frailty of human perception
# love story is not believable at all
# love of film-making
# love that Dean Stockwell, Quantum Leap - Al, is the little boy
# love , something he has longed for, and now finds fulfillment
# love John Candy's humor, this is a must-see
# love with his fiancée, on seeing a strange man come out of her bathroom as happens here, would knock the lights out of him and cause a huge scene
# love triangle" story in this film; the soldier turns sour as he slowly and subtly moves in on the woman and then eventually kisses her when she already has a boyfriend; most of the family practically applauds this behavior - the family goes with Church and participates in services, yet this is how they act; there is some bad language <br /><br />Conclusion: I became disappointed as the film ran on, and it got worse and worse
# love the fashion of the '70s (except Streisand's afro
# love with secretary Lauren Bacall
# love and just basically have fun, all sorts of things that don't really make them any different than any other horror film victims seen previously
# love my way
# love of animals, the gentle and subdued way he treated women) and so on
# love triangle between The Kid, Appolonia and Morris Day was so predictable and tired that I actually became insulted
# love and respect for the "art"
# love with Harris
# love story, characters have to overcome their short-givings, villain has to emerge, but none of it ever initiated
# love and find success in their careers
# love with Princeton mathematics doctoral candidate Catherine Boyd (Meg Ryan)
# love Al Pacino, it was painful to see him in this movie
# love between a male human and a female demon leads to a great story for a new Kabuki theater piece
# love mystery-horror films like this
# love interest (the female tailor
# love 80s metal and bad movies, this one's for you
# love after dealing with a old fashioned grandmother and a girl who he wants to use is actually using him too
# love one another and how misunderstood the old man has been by his children
# love for Albert, and their happy family life together, was one of the main reasons why the monarchy succeeded in reestablishing itself in the affections of the British people
# love and sexual liberation, has been reduced by time to a mere curiosity
# love to provide others the same opportunity I had - seeing it with no prior knowledge of what to expect
# love interest for Cathy Lee
# love and of the common man whom he ignored, here embodied by the little thief (Sabu)
# love "Bend it Like Beckham
# love the line about Oscar's refrigerator, "It's been out of order for two weeks, I saw milk standing in there that wasn't even in a bottle
# love is, to put it frankly, unattractive
# love life again, pushing past all the pressures of work and money to discover joy once more
# love this movie foe some reason
# love for Wood's script
# love his films but I am completely unsure about his range
# love in Nora, Fay Johnson, a writer for a local love magazine
# love twist
# love a movie that succeeds without it
# love for their children
# love story between Ben and Abigail
# love the sets and the location
# love to her
# love with a tea plantation owner from British Ceylon (current day Sri Lanka)
# love with themselves, for one thing
# love the major hoaky scene where the bats stripped her nekkid; I don't know if I've ever seen anything more ludicrous yet sexy at the same time
# love some special effects, they are really cheesy and bad
# love Salma Hayek
# love with another woman, and why is the final moment of the film dedicated to a wife that our main character hasn't even cared about through most of the film
# love him and vice-versa
# love in the sand
# love it or hate it', very few people i have seen introduced to this series will end up with a distaste for it
# love to hear about it & where it can be purchased
# love stupid movies
# love low budget movies
# love to be part of it
# love for this film - after I watched it for the first time, jaw-dropped, I rewound it and watched it again
# love of God, do not watch this movie
# love with (I guess that's Robert Foxworth) turns out also to be the guy Satan wants to marry her off to, The Demon with Yellow Eyes, and yep, sure enough, they show Robert Foxworth, and his eyes glow yellow
# love the message
# love with asymmetrical Grayson, but she predictably treats him with contempt until they finally hook up
# love Robert Culp and Patricia Crowley and Ray Milland in their roles but the story was weaker in this episode than in the others
# love the old woman in the basement
# love it and call it work of genious
# love to see this get nominated for best picture and I would love to see Cruz up for best Actress, Diaz for best supporting, Cruise for best actor and Jason Mewes should be a shoe in for best supporting actor
# love this series and you will not be disappointed with your purchase
# love the way this movie just envelops the audience in its space, and makes you think, however jaded you may be, that you are one of those characters
# love and peace
# love any movie that includes male nudity for a change
# love it or dislike it
# love triangle thing
# love interest, a rather threadbare, unlikeable woman who can't give him the time of day until he becomes a big shot -- if you're like me, you'll be hoping that he gives her the shove-off at the end
# love to screen this film, and not the original) or rent it cheap, but please don't buy it, whatever you do
# love that is supposed to be between Jane and Rochester and the movie left me totally unmoved
# love with her and decides that as her condition has worsened he needs to make his donation
# love to hear from those that have an opinion on this subject

# %% [markdown]
# Look at the results -- does the regular expression correctly return sentences containing 'love'?
#
# There are lots more special characters that you can use to form really powerful regular expressions for segmenting, retrieving and substituting text. For your reference, you can find a complete list [here](https://docs.python.org/3/library/re.html#regular-expression-syntax).

# %% [markdown]
# ## 2.2 Substitution
#
# We can also use regular expressions during _preprocessing_ to clean up text and prepare it for further analysis. For this, we use regular expression _substitution_, which finds a matching string within a larger piece of text, and replaces it with another string.
#
# Let's use this to clean up the text by removing the line break characters.
#
# In Python, we can use the re.sub() function, which takes three arguments:
# 1. The expression to match.
# 2. The pattern we should replace it with
# 3. The text to apply the subtitution to.
#
# Some of the reviews contain some HTML formatting code, `<br />`, which we can try to remove to clean up the text. We can do this by writing an expression for the first argument of re.sub() that matches '<br />'. Take a look at how this works by running the code below:

# %%
print('ORIGINAL TEXT: ')
print(train_dataset[0]['text'])
    
clean_article = re.sub(r'<br />', r' ', train_dataset[0]['text'])  # replace HTML breaks with a space
    
print('CLEANER TEXT: ')
print(clean_article)
# Out:
# ORIGINAL TEXT:
# Despite its low-key release in this country, and its apparent disregard in other countries (the 'R' rating in the States can't have helped - honestly, just because HBC uses the C-word!), this is actually a fine piece of work. The sentimentality does occasionally threaten to choke it, but it's overcome by the playing of the two leads.<br /><br />It's easy to win plaudits just because you're playing a physical or mental cripple (Daniel Day-Lewis, Geoffrey Rush, Dustin Hoffman, etc.), and Helena Bonham-Carter may not quite capture the physical degradation of MND, but her vocal stretching and ruthless emotional drive compensate entirely. In fact, almost all her performance is conducted through her eyes (and what eyes!). This is an intelligent turn from an actress who is rapidly undoing her English Rose reputation, and emerging as a figure of some stature. Awards must surely follow, though not, alas, for this fine performance.<br /><br />Branagh, one feels, has never quite given his best on film (except possibly 'Hamlet', and there his playing was diluted by the large cast). Here, though, he tops his other appearances, playing to the hilt a self-loathing, unstable, ultimately lovable guy with a subtlety he hasn't always displayed, and exhibiting both intelligence and depth. In short, we believe him, just as much as we could NOT believe him as Frankenstein, as the priest in 'The Proposition', as the lawyer in 'The Gingerbread Man', even as Andrew in 'Peter's Friends'. This is surely his finest performance yet - so why could he not produce the goods much earlier?<br /><br />As a film, it looks more like a television offering, and without its stars it probably wouldn't amount to very much. But it's been a pleasure to see this pair perform their socks off like this, and I eagerly await more from them (though not 'Love's Labour's Lost'...). 8 out of 10, but Branagh and HBC get 10 out of 10.
# CLEANER TEXT:
# Despite its low-key release in this country, and its apparent disregard in other countries (the 'R' rating in the States can't have helped - honestly, just because HBC uses the C-word!), this is actually a fine piece of work. The sentimentality does occasionally threaten to choke it, but it's overcome by the playing of the two leads.  It's easy to win plaudits just because you're playing a physical or mental cripple (Daniel Day-Lewis, Geoffrey Rush, Dustin Hoffman, etc.), and Helena Bonham-Carter may not quite capture the physical degradation of MND, but her vocal stretching and ruthless emotional drive compensate entirely. In fact, almost all her performance is conducted through her eyes (and what eyes!). This is an intelligent turn from an actress who is rapidly undoing her English Rose reputation, and emerging as a figure of some stature. Awards must surely follow, though not, alas, for this fine performance.  Branagh, one feels, has never quite given his best on film (except possibly 'Hamlet', and there his playing was diluted by the large cast). Here, though, he tops his other appearances, playing to the hilt a self-loathing, unstable, ultimately lovable guy with a subtlety he hasn't always displayed, and exhibiting both intelligence and depth. In short, we believe him, just as much as we could NOT believe him as Frankenstein, as the priest in 'The Proposition', as the lawyer in 'The Gingerbread Man', even as Andrew in 'Peter's Friends'. This is surely his finest performance yet - so why could he not produce the goods much earlier?  As a film, it looks more like a television offering, and without its stars it probably wouldn't amount to very much. But it's been a pleasure to see this pair perform their socks off like this, and I eagerly await more from them (though not 'Love's Labour's Lost'...). 8 out of 10, but Branagh and HBC get 10 out of 10.

# %% [markdown]
# # 3. Text Normalisation
#
# For most text analytics tasks, we will first need to transform the raw text to a suitable format for input to method such as a classifier. This process is called _text normalisation_ and is part of the _preprocessing_ stage. There are three common steps:
#
# 1. Sentence segmentation: we have already tried out a basic approach to obtaining complete sentences using regular expressions. This would need to be modified to return a list of all sentences in a document.
# 2. Tokenisation, in which the sentences are split into a sequence of tokens, which include words, numbers and punctuation marks.
# 3. Word normalisation, in which different forms of a word are replaced by a root form.
#
# We are now going to see how to perform these steps using the NLTK library.
#
# ## 3.1 Sentence Segmentation
#
# Let's start by using NLTK to split a document into sentences. This should give better results than our regular expressions above.
#
# You may get some errors from NLTK when you try to use sent_tokenize or word_tokenize further down. This is usually because you need to download and install some NLTK data. Please check the error message to find out which package is required. You probably need to install packages called 'punkt' and 'wordnet'. You can install these packages by running the cell below.

# %%
import nltk 

# nltk.download('punkt_tab')


nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /Users/sisjkly/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/sisjkly/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
import nltk

review = train_dataset[3]['text']

sents = nltk.sent_tokenize(review)

for sent in sents[:5]:
    print("<SENTENCE>")
    print(sent)  # print the first five sentences of this document
# Out:
# <SENTENCE>
# Because some people, like me, like to know EVERYTHING about a movie even if they plan to see it, including the ending.
# <SENTENCE>
# Anyway, here's the ending as I remember it, because I couldn't have been more than 8 yrs old when I saw it for the first and only time on TV.
# <SENTENCE>
# But I'll tell ya, it sure scared the little kid that I was, and I thought about it for days afterward, and it still stands out in my mind to this day, even though some of the details are a little vague.
# <SENTENCE>
# Abe Vigoda was in this movie?
# <SENTENCE>
# I don't remember that!

# %% [markdown]
# TODO 3: Use the regular expression substitution code from section 2.2 to remove the '\<br /\>' tags from the sentences displayed above and print the results.

# %%
clean_sents = []

for sent in sents[:5]:
    
    ### WRITE YOUR OWN CODE HERE
    sent = re.sub(r'<br />', r' ', sent)  # replace HTML breaks with a space
    #######
    
    print("<SENTENCE>")
    print(sent)  # print the first five sentences of this document
    
    clean_sents.append(sent)  # save the cleaned sentences for later
# Out:
# <SENTENCE>
# Because some people, like me, like to know EVERYTHING about a movie even if they plan to see it, including the ending.
# <SENTENCE>
# Anyway, here's the ending as I remember it, because I couldn't have been more than 8 yrs old when I saw it for the first and only time on TV.
# <SENTENCE>
# But I'll tell ya, it sure scared the little kid that I was, and I thought about it for days afterward, and it still stands out in my mind to this day, even though some of the details are a little vague.
# <SENTENCE>
# Abe Vigoda was in this movie?
# <SENTENCE>
# I don't remember that!

# %% [markdown]
# ## 3.2 Tokenisation
#
# NLTK provides a similar function for tokenizing the text at the word level. You can find the documentation [here](https://www.nltk.org/api/nltk.tokenize.html). Most tokenizers use either regular expressions or a machine learning model that was trained on a large dataset to learn token-splitting rules.
#
# TODO 4: Use word_tokenize() to tokenize each of the sentences from the last cell.

# %%
from nltk.tokenize import word_tokenize
tokenized_sents = []

for sent in clean_sents:
    ### WRITE YOUR OWN CODE HERE
    tokens = word_tokenize(sent)
    #######
    
    print("<TOKENS>")
    print(tokens)
    
    tokenized_sents.append(tokens)
# Out:
# <TOKENS>
# ['Because', 'some', 'people', ',', 'like', 'me', ',', 'like', 'to', 'know', 'EVERYTHING', 'about', 'a', 'movie', 'even', 'if', 'they', 'plan', 'to', 'see', 'it', ',', 'including', 'the', 'ending', '.']
# <TOKENS>
# ['Anyway', ',', 'here', "'s", 'the', 'ending', 'as', 'I', 'remember', 'it', ',', 'because', 'I', 'could', "n't", 'have', 'been', 'more', 'than', '8', 'yrs', 'old', 'when', 'I', 'saw', 'it', 'for', 'the', 'first', 'and', 'only', 'time', 'on', 'TV', '.']
# <TOKENS>
# ['But', 'I', "'ll", 'tell', 'ya', ',', 'it', 'sure', 'scared', 'the', 'little', 'kid', 'that', 'I', 'was', ',', 'and', 'I', 'thought', 'about', 'it', 'for', 'days', 'afterward', ',', 'and', 'it', 'still', 'stands', 'out', 'in', 'my', 'mind', 'to', 'this', 'day', ',', 'even', 'though', 'some', 'of', 'the', 'details', 'are', 'a', 'little', 'vague', '.']
# <TOKENS>
# ['Abe', 'Vigoda', 'was', 'in', 'this', 'movie', '?']
# <TOKENS>
# ['I', 'do', "n't", 'remember', 'that', '!']

# %% [markdown]
# Run the code below to see how NLTK has handled the non-letter characters.
# * What does it do with most punctuation marks?
# * When does it not split tokens based on punctuation?

# %%
for sent in tokenized_sents:
    for tok in sent:
        if re.search(r'[^a-zA-Z0-9]', tok):  # find the non-letter and non-digit characters
            print(tok)  # print the entire token containing the non-letter/non-digit character
# Out:
# ,
# ,
# ,
# .
# ,
# 's
# ,
# n't
# .
# 'll
# ,
# ,
# ,
# ,
# .
# ?
# n't
# !

# %% [markdown]
# ## 3.3 Word Normalisation
#
# Many words can appear in different forms, including:
# * Conjugated verbs
# * Plural and singular nouns
# * Common abbrevations and synonyms like "USA" and "US".
#
# Mapping all of these surface forms to a single root form reduces the size of the vocabulary that we have to deal with and can therefore improve the performance of text classifiers or topic models.
#
# The two most widely used tools for this task in English are the Porter Stemmer and WordNet Lemmatizer. These tools apply a series of regular expression substitutions to tokenised text to convert words to a standard format.
# * The Porter stemmer is much faster but just removes word prefixes and endings, which leads to some errors. It is often used when real-time or high-volume text processing is needed.
# * As well as applying regular expressions, lemmatizers look words up in a dictionary to find their root forms, so are more accurate but much slower.
#
# Let's start by applying the [Porter Stemmer class](https://www.nltk.org/_modules/nltk/stem/porter.html) to our tokenised text by calling the stem() method:

# %%
stemmer = nltk.PorterStemmer() 
stemmed_sents = []

for sent in tokenized_sents:
    stemmed_sent = [stemmer.stem(tok) for tok in sent]
    
    stemmed_sents.append(stemmed_sent)
    
    print("<STEMMED TOKENS>")
    print(stemmed_sent)
# Out:
# <STEMMED TOKENS>
# ['becaus', 'some', 'peopl', ',', 'like', 'me', ',', 'like', 'to', 'know', 'everyth', 'about', 'a', 'movi', 'even', 'if', 'they', 'plan', 'to', 'see', 'it', ',', 'includ', 'the', 'end', '.']
# <STEMMED TOKENS>
# ['anyway', ',', 'here', "'s", 'the', 'end', 'as', 'i', 'rememb', 'it', ',', 'becaus', 'i', 'could', "n't", 'have', 'been', 'more', 'than', '8', 'yr', 'old', 'when', 'i', 'saw', 'it', 'for', 'the', 'first', 'and', 'onli', 'time', 'on', 'tv', '.']
# <STEMMED TOKENS>
# ['but', 'i', "'ll", 'tell', 'ya', ',', 'it', 'sure', 'scare', 'the', 'littl', 'kid', 'that', 'i', 'wa', ',', 'and', 'i', 'thought', 'about', 'it', 'for', 'day', 'afterward', ',', 'and', 'it', 'still', 'stand', 'out', 'in', 'my', 'mind', 'to', 'thi', 'day', ',', 'even', 'though', 'some', 'of', 'the', 'detail', 'are', 'a', 'littl', 'vagu', '.']
# <STEMMED TOKENS>
# ['abe', 'vigoda', 'wa', 'in', 'thi', 'movi', '?']
# <STEMMED TOKENS>
# ['i', 'do', "n't", 'rememb', 'that', '!']

# %% [markdown]
# Now let's compare the stemming results to lemmatisation. For this task, NLTK provides the [class WordNetLemmatizer](https://www.nltk.org/_modules/nltk/stem/wordnet.html) with the method lemmatize(). This method takes an argument, `pos`, that determines whether the lemmatizer is applied to nouns, verbs, adjectives or adverbs.
#
# TODO 5: Use the WordNetLemmatizer to lemmatize the nouns in the tokenized sentences. Set the `pos` argument to 'n'.
#
# TODO 6: Add a second call to lemmatize() to lemmatize the verbs in the sentences as well. Set the `pos` argument to 'v'.
#
# How do the results compare with the Porter stemmer?
#
# How have the verbs in the sentences changed?

# %%
lemmatizer = nltk.WordNetLemmatizer() 
lemma_sents = []
for sent in tokenized_sents:
    
    ### WRITE YOUR OWN CODE HERE

    lemma_sent = [lemmatizer.lemmatize(word, pos='n') for word in sent]
    
    #######
    
    lemma_sents.append(lemma_sent)
    
    print("<LEMMATIZED TOKENS>")
    print(lemma_sent)
# Out:
# <LEMMATIZED TOKENS>
# ['Because', 'some', 'people', ',', 'like', 'me', ',', 'like', 'to', 'know', 'EVERYTHING', 'about', 'a', 'movie', 'even', 'if', 'they', 'plan', 'to', 'see', 'it', ',', 'including', 'the', 'ending', '.']
# <LEMMATIZED TOKENS>
# ['Anyway', ',', 'here', "'s", 'the', 'ending', 'a', 'I', 'remember', 'it', ',', 'because', 'I', 'could', "n't", 'have', 'been', 'more', 'than', '8', 'yr', 'old', 'when', 'I', 'saw', 'it', 'for', 'the', 'first', 'and', 'only', 'time', 'on', 'TV', '.']
# <LEMMATIZED TOKENS>
# ['But', 'I', "'ll", 'tell', 'ya', ',', 'it', 'sure', 'scared', 'the', 'little', 'kid', 'that', 'I', 'wa', ',', 'and', 'I', 'thought', 'about', 'it', 'for', 'day', 'afterward', ',', 'and', 'it', 'still', 'stand', 'out', 'in', 'my', 'mind', 'to', 'this', 'day', ',', 'even', 'though', 'some', 'of', 'the', 'detail', 'are', 'a', 'little', 'vague', '.']
# <LEMMATIZED TOKENS>
# ['Abe', 'Vigoda', 'wa', 'in', 'this', 'movie', '?']
# <LEMMATIZED TOKENS>
# ['I', 'do', "n't", 'remember', 'that', '!']

# %%
for sent in tokenized_sents:
    
    ### WRITE YOUR OWN CODE HERE

    lemma_sent = [lemmatizer.lemmatize(word, pos='v') for word in sent]
    
    #######
    
    lemma_sents.append(lemma_sent)
    
    print("<LEMMATIZED TOKENS>")
    print(lemma_sent)
# Out:
# <LEMMATIZED TOKENS>
# ['Because', 'some', 'people', ',', 'like', 'me', ',', 'like', 'to', 'know', 'EVERYTHING', 'about', 'a', 'movie', 'even', 'if', 'they', 'plan', 'to', 'see', 'it', ',', 'include', 'the', 'end', '.']
# <LEMMATIZED TOKENS>
# ['Anyway', ',', 'here', "'s", 'the', 'end', 'as', 'I', 'remember', 'it', ',', 'because', 'I', 'could', "n't", 'have', 'be', 'more', 'than', '8', 'yrs', 'old', 'when', 'I', 'saw', 'it', 'for', 'the', 'first', 'and', 'only', 'time', 'on', 'TV', '.']
# <LEMMATIZED TOKENS>
# ['But', 'I', "'ll", 'tell', 'ya', ',', 'it', 'sure', 'scar', 'the', 'little', 'kid', 'that', 'I', 'be', ',', 'and', 'I', 'think', 'about', 'it', 'for', 'days', 'afterward', ',', 'and', 'it', 'still', 'stand', 'out', 'in', 'my', 'mind', 'to', 'this', 'day', ',', 'even', 'though', 'some', 'of', 'the', 'detail', 'be', 'a', 'little', 'vague', '.']
# <LEMMATIZED TOKENS>
# ['Abe', 'Vigoda', 'be', 'in', 'this', 'movie', '?']
# <LEMMATIZED TOKENS>
# ['I', 'do', "n't", 'remember', 'that', '!']

# %% [markdown]
# # 4. Classification
#
# In this part, we will introduce text processing tools from the scikit-learn library. Let's start by loading the test set for the IMDB sentiment dataset.
#
# ## 4.1 Preprocessing

# %%
# Load the test set:
test_dataset = load_dataset(
    "imdb",
    split="test",
    cache_dir=cache_dir,
)
print(f"Test dataset with {len(test_dataset)} instances loaded")

test_dataset = np.random.choice(test_dataset, 2000, replace=False)  # we'll only use a subset of the data in this lab so that the code runs quicker
# Out:
# Test dataset with 25000 instances loaded

# %% [markdown]
# The next step is to tokenise the text of each tweet and convert it to a bag of words, ready for input to a classifier.
# To do this, we will use the scikit-learn library.

# %% [markdown]
# To extract a bag of words, we can use the CountVectorizer class ([documentation](https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.CountVectorizer.html)).
# This class outputs the bag of words as a feature vector, where the length of the vector is equal to the size of the vocabulary, and the values are the counts of each words in a document.
#
# Run the code below to obtain feature vectors for the training and test samples:

# %%
train_text = [sample["text"] for sample in train_dataset]
train_label = [sample["label"] for sample in train_dataset]
test_text = [sample["text"] for sample in test_dataset]
test_label =  [sample["label"] for sample in test_dataset]

# %%
from sklearn.feature_extraction.text import CountVectorizer
from nltk import word_tokenize

# CountVectorizer can do its own tokenization, but for consistency we want to
# carry on using WordNetTokenizer. 
vectorizer = CountVectorizer(tokenizer=word_tokenize)  # construct the vectorizer

vectorizer.fit(train_text)  # Learn the vocabulary
X_train = vectorizer.transform(train_text)  # extract training set bags of words
X_test = vectorizer.transform(test_text)  # extract test set bags of words
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/feature_extraction/text.py:521: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(

# %% [markdown]
# The fit() method sets the vectorizer up by extracting a vocabulary from some text data.
#
# QUESTION: Why do we fit the CountVectorizer on the training set only?
#
# The vectorizer stores the vocabulary as a dictionary that maps a token to its index in the feature vector. The code below looks up the indexes of some example words:

# %%
import reprlib

vocabulary = vectorizer.vocabulary_
print(vocabulary['the'])
print(vocabulary['horse'])
print(vocabulary['smile'])
print(vocabulary['happy'])
print(vocabulary['hate'])

print(f'Vocabulary size = {len(vocabulary)}')
# Out:
# 43926
# 21756
# 40505
# 20501
# 20666
# Vocabulary size = 49318

# %% [markdown]
# ## 4.2 Naive Bayes Classifier
#
# The code above has obtained the feature vectors and lists of labels. The data is now ready for use
# with scikit-learn's classifiers.
#
# Scikit-learn contains several different variants of naïve Bayes for different kinds of data. For our bag of words data, we need to use the [MultinomialNB class](https://scikit-learn.org/stable/modules/generated/sklearn.naive_bayes.MultinomialNB.html#sklearn.naive_bayes.MultinomialNB).
#
#
# TODO 7: Look at the documentation for MultinomalNB and write code to train a NB classifier using `X_train` and `train_label`.

# %%
# WRITE YOUR CODE HERE
from sklearn.naive_bayes import MultinomialNB
clf = MultinomialNB()
clf.fit(X_train, train_label)
# Out:
# MultinomialNB()

# %% [markdown]
# Now we have a trained model, we would like to evaluate its performance on some test data.
#
# TODO 8: Refer to the documentation again and predict the labels for the test set. Use `X_test` as the inputs to the classifier.

# %%
# WRITE YOUR CODE HERE
predict = clf.predict(X_test)

# %% [markdown]
# We can compute metrics for classifier performance using [scikit-learn's metrics libary](https://scikit-learn.org/stable/modules/model_evaluation.html#the-scoring-parameter-defining-model-evaluation-rules). A useful function for multi-class classification (when there are more than two classes) is the [classification report function](https://scikit-learn.org/stable/modules/model_evaluation.html#classification-report).
#
# TODO 9: Refer again to the documentation, and compute accuracy, precision, recall and F1 scores on the test set.

# %%
# WRITE YOUR CODE HERE
from sklearn.metrics import classification_report
print(classification_report(test_label, predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.88      0.83      1036
#            1       0.85      0.75      0.80       964
#
#     accuracy                           0.82      2000
#    macro avg       0.82      0.81      0.81      2000
# weighted avg       0.82      0.82      0.81      2000

# %% [markdown]
# Now, let's examine the classifier that we learned. You may wish to refer back to the slides on naïve Bayes classifiers or to [Jurafsky and Martin's textbook](https://web.stanford.edu/~jurafsky/slp3/4.pdf) to see how the implementation relates to the equations.
#
# Previously, we trained a MultinomialNB classifier. The trained classifier object stores all the probabilities that it learned during training, which are needed to make predictions. The log of the likelihoods of each word given the class are represented by the attribute `feature_log_prob_`. So, if your classifier object is named `classifier`, you can access the log likelihoods with `classifier.feature_log_prob_`.
#
# TODO 10: Print out the likelihood of the words 'happy' and 'hate' in each class. Hint: look up the index of the chosen words in `vocabulary`. The rows of `feature_log_prob` correspond to classes, and the columns to words.

# %%
import numpy as np

### CHANGE THE NAME OF THE CLASSIFIER VARIABLE BELOW TO USE YOUR TRAINED CLASSIFIER
feat_likelihoods = np.exp(clf.feature_log_prob_)  # Use exponential to convert the logs back to probabilities
###

# WRITE YOUR CODE HERE
print(feat_likelihoods[1][20501]) # happy
print(feat_likelihoods[1][20666]) # hate
# Out:
# 0.00016494951642729658
# 8.11860901165599e-05

# %% [markdown]
# The sentiment classes are negative (0) and positive (1).
#
# QUESTION: According to the feature log likelihoods, which class has the strongest association with 'happy' and with 'hate'?
#
# A key part of evaluating a classifier is investigating the errors it makes to better understand its limitations.
#
# TODO 11: Complete the code below to print out some misclassified reviews along with their predicted and true labels. Can you see any reasons why a NB classiier would make mistakes with these instances?

# %%
error_indexes = y_test_pred != test_label  # compare predictions to gold labels

# get the text of reviews where the classifier made an error:
reviews_err = np.array(test_text)[error_indexes]

# WRITE YOUR CODE HERE

# %% [markdown]
# ## 4.3. Logistic Regression Classifier
#
# Another simple, linear classifier is logistic regression. This classifier does not rely on the conditional independence assumption, so can better model features that are highly correlated with each other. Scikit-learn provides the [logisticRegression class](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html), which has a very similar interface to the naïve Bayes classifier.
#
# TODO 12: Train a logistic regression classifier, referring to the scikit-learn documentation as required.

# %%
# WRITE YOUR CODE HERE

# %%
# WRITE YOUR CODE HERE

# %%
# WRITE YOUR CODE HERE

# %% [markdown]
# QUESTION: How does the performance of logistic regression compare with naïve Bayes?
#
# The logistic regression classifier works by learning a weight for each feature that indicates its importance in predicting a class. These weights are stored in the `coef_` attribute of the LogisticRegression object. For the binary case, it provides a single weight per feature. This allows it to compute the probability of the positive class as _p_, then compute the probability of the negative class as _1-p_.  For multi-class problems, there is a row of weights corresponding to each class, and columns corresponding to words in the vocabulary.
#
# TODO 13: Print out the weights for 'happy' and 'hate'.

# %%
### WRITE YOUR CODE HERE

# %% [markdown]
# QUESTION: Are the weights what you would expect to see?
#
# The code below prints out the words with the highest weights for the positive class. We use numpy's `argsort` function to get the indexes of the sorted weights. Run the code below to show the result:

# %%
n_feats_to_show = 10

# Flip the index so that values are keys and keys are values:
keys = vectorizer.vocabulary_.values()
values = vectorizer.vocabulary_.keys()
vocab_inverted = dict(zip(keys, values))

strongest_idxs = np.argsort(classifier.coef_[0])[-n_feats_to_show:]

for idx in strongest_idxs:
    print(f'{vocab_inverted[idx]} with weight {classifier.coef_[0][idx]}')

# %% [markdown]
# TODO 14: Use the same code as for naïve Bayes to print out examples of misclassified tweets and their labels. Hint: you should be able to copy and paste your code from above :)

# %%
error_indexes = y_test_pred != test_label  # compare predictions to gold labels

# get the text of tweets where the classifier made an error:
reviews_err = np.array(test_text)[error_indexes]

# WRITE YOUR CODE HERE

# %% [markdown]
# # 5. OPTIONAL: Lemmatization and N-grams
#
# You only need to do this section if you finish the previous sections before the end of the lab.
#
# In the previous lab, we tried out lemmatization. This is useful for reducing the size of the vocabulary. Could it help us here?
#
# To apply lemmatization, we have to go back to the CountVectorizer and define a new tokenizer class that will carry out the extra step of lemmatization. Run the code below to test this out:

# %%
from nltk import word_tokenize          
from nltk.stem import WordNetLemmatizer 

class LemmaTokenizer(object):  # this 'tokenizer' will also do additional preprocessing steps, namely, lemmatize verbs and adjectives
    
    def __init__(self):
        self.wnl = WordNetLemmatizer()
        
    def __call__(self, tweets):
        return [self.wnl.lemmatize(self.wnl.lemmatize(tok, pos='v'), pos='a') for tok in word_tokenize(tweets)]
    
vectorizer = CountVectorizer(tokenizer=LemmaTokenizer())

vectorizer.fit(train_text)
X_train = vectorizer.transform(train_text)
X_test = vectorizer.transform(test_text)

# Print out some of the features in the vocabulary:
print(list(vectorizer.vocabulary_)[:20])

# %%
print(f'Vocabulary size: {len(vectorizer.vocabulary_)}')

# %% [markdown]
# TODO 15: Now, repeat your training of the NB classifier using the new features, and compare its performance with the previous classifers.

# %%
### WRITE YOUR OWN CODE HERE

# %% [markdown]
# QUESTION: Did lemmatization bring about any improvements on this dataset?
#
# The bag of words is a very simple representation of the text that does not capture enough information to make accurate sentiment classifications. Another way to improve it could be to use bigrams instead of single words as our features. Bigrams are pairs of words that occur one after another in the text. Bigrams are a kind of 'n-gram', where 'n=2'.
#
# To extract bigrams, we again modify our CountVectorizer. This class has a parameter `ngram_range`, which determines the range of sizes of n-grams the vectorizer will include. If we set `ngram_range=(1,1)` we have our standard bag of words. If we set it to `ngram_range=(2,2)`, we use bigrams instead. Choosing If we set `ngram_range=(1,2)` will use both single tokens (unigrams) and bigrams.
#
# TODO 16: Create a new CountVectorizer that extracts bigram features as well as unigrams (single tokens).

# %%
### WRITE YOUR CODE HERE



###

print(f'Vocabulary size: {len(vectorizer.vocabulary_)}')

# Print out some of the features in the vocabulary:
print(list(vectorizer.vocabulary_)[:20])

# %% [markdown]
# TODO 17: Now, repeat your training of the logistic regression or naïve Bayes classifier using the new features, and compare its performance with the previous classifers.

# %%
### WRITE YOUR OWN CODE HERE

# %% [markdown]
# QUESTION: Do bigrams improve performance on this dataset?
#
# # 6. Optional: Lexicon Features
#
# You only need to do this part if you finish the other parts before the end of the lab session.
#
# The NLTK library contains sentiment lexicons, which are lists of words with negative or positive connotations.

# %%
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer

nltk.download('vader_lexicon')

analyser = SentimentIntensityAnalyzer()

# %% [markdown]
# Let's have a look at the sentiment scores for some words in the lexicon by running the code below. What do the scores mean and why do some words have no score?

# %%
testwords = ['happy', 'wonderful', 'horrible', 'boring', 'tablecloth', 'not']

for word in testwords:
    if word in analyser.lexicon:
        print(f'{word}: {analyser.lexicon[word]}')
    else:
        print(f'{word}: NOT IN LEXICON')

# %% [markdown]
# Now we would like to use this function to compute counts of all positive and negative words. Let's start by recording whether the words in our vocabulary are positive or negative:

# %%
# Print out some of the features in the vocabulary:
print(list(vectorizer.vocabulary_)[:20])

vocabulary = vectorizer.vocabulary_

lex_pos_scores = np.zeros((1, len(vocabulary)))
lex_neg_scores = np.zeros((1, len(vocabulary)))

# get the Vader lexicon scores for each word in our vocabulary
for i, term in enumerate(vocabulary):
    if term in analyser.lexicon and analyser.lexicon[term] > 0:
        lex_pos_scores[0, i] = 1
    elif term in analyser.lexicon and analyser.lexicon[term] < 0:
        lex_neg_scores[0, i] = 1

# %% [markdown]
# Now let's compute the counts of positive and negative words in the dataset:

# %%
# Compute the scores for each instance in the data set. 

# Multiply the lexicon scores by the feature vectors, then sum over the 
# vocabulary to get the total positive and total negative counts:
lex_pos_train = np.sum(X_train.multiply(lex_pos_scores), axis=1)
lex_pos_test = np.sum(X_test.multiply(lex_pos_scores), axis=1)

lex_neg_train = np.sum(X_train.multiply(lex_neg_scores), axis=1)
lex_neg_test = np.sum(X_test.multiply(lex_neg_scores), axis=1)

# %% [markdown]
# Finally, we can append the counts to the feature vector and treat them as extra features:

# %%
from scipy.sparse import hstack

X_train = hstack((X_train, lex_pos_train, lex_neg_train))
X_test = hstack((X_test, lex_pos_test, lex_neg_test))

# %% [markdown]
# TO-DO 18: Use the new X_train and X_test feature vectors to train and evaluate your classifier.
# Does adding the lexicon features improve performance?

# %%
### WRITE YOUR OWN CODE HERE
